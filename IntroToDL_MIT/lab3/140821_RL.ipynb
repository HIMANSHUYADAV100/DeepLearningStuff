# %% [markdown]
# <a href="https://colab.research.google.com/github/HIMANSHUYADAV100/DeepLearningStuff/blob/main/IntroToDL_MIT/lab3/140821_RL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <table align="center">
#   <td align="center"><a target="_blank" href="http://introtodeeplearning.com">
#         <img src="https://i.ibb.co/Jr88sn2/mit.png" style="padding-bottom:5px;" />
#       Visit MIT Deep Learning</a></td>
#   <td align="center"><a target="_blank" href="https://colab.research.google.com/github/aamini/introtodeeplearning/blob/master/lab3/RL.ipynb">
#         <img src="https://i.ibb.co/2P3SLwK/colab.png"  style="padding-bottom:5px;" />Run in Google Colab</a></td>
#   <td align="center"><a target="_blank" href="https://github.com/aamini/introtodeeplearning/blob/master/lab3/RL.ipynb">
#         <img src="https://i.ibb.co/xfJbPmL/github.png"  height="70px" style="padding-bottom:5px;"  />View Source on GitHub</a></td>
# </table>
#
# # Copyright Information

# %%
# Copyright 2021 MIT 6.S191 Introduction to Deep Learning. All Rights Reserved.
# 
# Licensed under the MIT License. You may not use this file except in compliance
# with the License. Use and/or modification of this code outside of 6.S191 must
# reference:
#
# © MIT 6.S191: Introduction to Deep Learning
# http://introtodeeplearning.com
#

# %% [markdown]
# # Laboratory 3: Reinforcement Learning
#
# Reinforcement learning (RL) is a subset of machine learning which poses learning problems as interactions between agents and environments. It often assumes agents have no prior knowledge of a world, so they must learn to navigate environments by optimizing a reward function. Within an environment, an agent can take certain actions and receive feedback, in the form of positive or negative rewards, with respect to their decision. As such, an agent's feedback loop is somewhat akin to the idea of "trial and error", or the manner in which a child might learn to distinguish between "good" and "bad" actions.
#
# In practical terms, our RL agent will interact with the environment by taking an action at each timestep, receiving a corresponding reward, and updating its state according to what it has "learned".
#
# ![alt text](https://www.kdnuggets.com/images/reinforcement-learning-fig1-700.jpg)
#
# While the ultimate goal of reinforcement learning is to teach agents to act in the real, physical world, games provide a convenient proving ground for developing RL algorithms and agents. Games have some properties that make them particularly well suited for RL:
#
# 1.   In many cases, games have perfectly describable environments. For example, all rules of chess can be formally written and programmed into a chess game simulator;
# 2.   Games are massively parallelizable. Since they do not require running in the real world, simultaneous environments can be run on large data clusters;
# 3.   Simpler scenarios in games enable fast prototyping. This speeds up the development of algorithms that could eventually run in the real-world; and
# 4.   ... Games are fun!
#
# In previous labs, we have explored both supervised (with LSTMs, CNNs) and unsupervised / semi-supervised (with VAEs) learning tasks. Reinforcement learning is fundamentally different, in that we are training a deep learning algorithm to govern the actions of our RL agent, that is trying, within its environment, to find the optimal way to achieve a goal. The goal of training an RL agent is to determine the best next step to take to earn the greatest final payoff or return. In this lab, we focus on building a reinforcement learning algorithm to master two different environments with varying complexity.
#
# 1.   **Cartpole**:   Balance a pole, protruding from a cart, in an upright position by only moving the base left or right. Environment with a low-dimensional observation space.
# 2.   [**Pong**](https://en.wikipedia.org/wiki/Pong): Beat your competitors (whether other AI or humans!) at the game of Pong. Environment with a high-dimensional observation space -- learning directly from raw pixels.
#
# Let's get started! First we'll import TensorFlow, the course package, and some dependencies.

# %%
#Install some dependencies for visualizing the agents
# !apt-get install -y xvfb python-opengl x11-utils > /dev/null 2>&1
# !pip install gym pyvirtualdisplay scikit-video > /dev/null 2>&1

# Import Tensorflow 2.0
# %tensorflow_version 2.x
import tensorflow as tf

import numpy as np
import base64, io, time, gym
import IPython, functools
import matplotlib.pyplot as plt
import time
from tqdm import tqdm

# Download and import the MIT 6.S191 package
# !pip install mitdeeplearning
import mitdeeplearning as mdl
# Out:
# Collecting mitdeeplearning
#   Downloading mitdeeplearning-0.2.0.tar.gz (2.1 MB)
#      |████████████████████████████████| 2.1 MB 8.4 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from mitdeeplearning) (1.19.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from mitdeeplearning) (2019.12.20)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from mitdeeplearning) (4.62.0)
# Requirement already satisfied: gym in /usr/local/lib/python3.7/dist-packages (from mitdeeplearning) (0.17.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym->mitdeeplearning) (1.4.1)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym->mitdeeplearning) (1.5.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym->mitdeeplearning) (1.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym->mitdeeplearning) (0.16.0)
# Building wheels for collected packages: mitdeeplearning
#   Building wheel for mitdeeplearning (setup.py) ... done
#   Created wheel for mitdeeplearning: filename=mitdeeplearning-0.2.0-py3-none-any.whl size=2115442 sha256=e936abf34182c04dbd53e70ab9601b4513c5c980b3557bb7e2e3279821d53bfd
#   Stored in directory: /root/.cache/pip/wheels/9a/b9/4f/99b7c8c5c75355550b83e1fcfc02956fb40c35eb01e2262877
# Successfully built mitdeeplearning
# Installing collected packages: mitdeeplearning
# Successfully installed mitdeeplearning-0.2.0

# %% [markdown]
# Before we dive in, let's take a step back and outline our approach, which is generally applicable to reinforcement learning problems in general:
#
# 1. **Initialize our environment and our agent**: here we will describe the different observations and actions the agent can make in the environemnt.
# 2. **Define our agent's memory**: this will enable the agent to remember its past actions, observations, and rewards.
# 3. **Define a reward function**: describes the reward associated with an action or sequence of actions.
# 4. **Define the learning algorithm**: this will be used to reinforce the agent's good behaviors and discourage bad behaviors.

# %% [markdown]
# # Part 1: Cartpole
#
# ## 3.1 Define the Cartpole environment and agent
#
# ### Environment
#
# In order to model the environment for both the Cartpole and Pong tasks, we'll be using a toolkit developed by OpenAI called [OpenAI Gym](https://gym.openai.com/). It provides several pre-defined environments for training and testing reinforcement learning agents, including those for classic physics control tasks, Atari video games, and robotic simulations. To access the Cartpole environment, we can use `env = gym.make("CartPole-v0")`, which we gained access to when we imported the `gym` package. We can instantiate different [environments](https://gym.openai.com/envs/#classic_control) by passing the enivronment name to the `make` function.
#
# One issue we might experience when developing RL algorithms is that many aspects of the learning process are inherently random: initializing game states, changes in the environment, and the agent's actions. As such, it can be helpful to set a initial "seed" for the environment to ensure some level of reproducibility. Much like you might use `numpy.random.seed`, we can call the comparable function in gym, `seed`, with our defined environment to ensure the environment's random variables are initialized the same each time.

# %%
### Instantiate the Cartpole environment ###

env = gym.make("CartPole-v0")
env.seed(1)
# Out:
# [1]

# %% [markdown]
# In Cartpole, a pole is attached by an un-actuated joint to a cart, which moves along a frictionless track. The pole starts upright, and the goal is to prevent it from falling over. The system is controlled by applying a force of +1 or -1 to the cart. A reward of +1 is provided for every timestep that the pole remains upright. The episode ends when the pole is more than 15 degrees from vertical, or the cart moves more than 2.4 units from the center of the track. A visual summary of the cartpole environment is depicted below:
#
# <img width="400px" src="https://danielpiedrahita.files.wordpress.com/2017/02/cart-pole.png"></img>
#
# Given this setup for the environment and the objective of the game, we can think about: 1) what observations help define the environment's state; 2) what actions the agent can take.
#
# First, let's consider the observation space. In this Cartpole environment our observations are:
#
# 1. Cart position
# 2. Cart velocity
# 3. Pole angle
# 4. Pole rotation rate
#
# We can confirm the size of the space by querying the environment's observation space:

# %%
n_observations = env.observation_space
print("Environment has observation space =", n_observations)
# Out:
# Environment has observation space = Box(-3.4028234663852886e+38, 3.4028234663852886e+38, (4,), float32)

# %% [markdown]
# Second, we consider the action space. At every time step, the agent can move either right or left. Again we can confirm the size of the action space by querying the environment:

# %%
n_actions = env.action_space.n
print("Number of possible actions that the agent can choose from =", n_actions)
# Out:
# Number of possible actions that the agent can choose from = 2

# %% [markdown]
# ### Cartpole agent
#
# Now that we have instantiated the environment and understood the dimensionality of the observation and action spaces, we are ready to define our agent. In deep reinforcement learning, a deep neural network defines the agent. This network will take as input an observation of the environment and output the probability of taking each of the possible actions. Since Cartpole is defined by a low-dimensional observation space, a simple feed-forward neural network should work well for our agent. We will define this using the `Sequential` API.

# %%
### Define the Cartpole agent ###

# Defines a feed-forward neural network
def create_cartpole_model():
  model = tf.keras.models.Sequential([
      # First Dense layer
      tf.keras.layers.Dense(units=32, activation='relu'),

      # '''TODO: Define the last Dense layer, which will provide the network's output.
      # # Think about the space the agent needs to act in!'''
      # [TODO: Dense layer]
      tf.keras.layers.Dense(units=n_actions)
  ])
  return model

cartpole_model = create_cartpole_model()

# %% [markdown]
# Now that we have defined the core network architecture, we will define an *action function* that executes a forward pass through the network, given a set of observations, and samples from the output. This sampling from the output probabilities will be used to select the next action for the agent. We will also add support so that the `choose_action` function can handle either a single observation or a batch of observations.
#
# **Critically, this action function is totally general -- we will use this function for both Cartpole and Pong, and it is applicable to other RL tasks, as well!**

# %%
### Define the agent's action function ###

# Function that takes observations as input, executes a forward pass through model, 
#   and outputs a sampled action.
# Arguments:
#   model: the network that defines our agent
#   observation: observation(s) which is/are fed as input to the model
#   single: flag as to whether we are handling a single observation or batch of
#     observations, provided as an np.array
# Returns:
#   action: choice of agent action
def choose_action(model, observation, single=True):
  # add batch dimension to the observation if only a single example was provided
  observation = np.expand_dims(observation, axis=0) if single else observation

  '''TODO: feed the observations through the model to predict the log 
  probabilities of each possible action.'''
  logits = model.predict(observation)
  
  '''TODO: Choose an action from the categorical distribution defined by the log 
      probabilities of each possible action.'''
  action = tf.random.categorical(logits, num_samples=1)

  action = action.numpy().flatten()

  return action[0] if single else action

# %% [markdown]
# ## 3.2 Define the agent's memory
#
# Now that we have instantiated the environment and defined the agent network architecture and action function, we are ready to move on to the next step in our RL workflow:
# 1. **Initialize our environment and our agent**: here we will describe the different observations and actions the agent can make in the environemnt.
# 2. **Define our agent's memory**: this will enable the agent to remember its past actions, observations, and rewards.
# 3. **Define the learning algorithm**: this will be used to reinforce the agent's good behaviors and discourage bad behaviors.
#
# In reinforcement learning, training occurs alongside the agent's acting in the environment; an *episode* refers to a sequence of actions that ends in some terminal state, such as the pole falling down or the cart crashing. The agent will need to remember all of its observations and actions, such that once an episode ends, it can learn to "reinforce" the good actions and punish the undesirable actions via training. Our first step is to define a simple `Memory` buffer that contains the agent's observations, actions, and received rewards from a given episode. We will also add support to combine a list of `Memory` objects into a single `Memory`. This will be very useful for batching, which will help you accelerate training later on in the lab.
#
# **Once again, note the modularity of this memory buffer -- it can and will be applied to other RL tasks as well!**

# %%
### Agent Memory ###

class Memory:
  def __init__(self): 
      self.clear()

  # Resets/restarts the memory buffer
  def clear(self): 
      self.observations = []
      self.actions = []
      self.rewards = []

  # Add observations, actions, rewards to memory
  def add_to_memory(self, new_observation, new_action, new_reward): 
      self.observations.append(new_observation)

      # '''TODO: update the list of actions with new action'''
      # # TODO: your update code here
      self.actions.append(new_action)

      # '''TODO: update the list of rewards with new reward'''
      # # TODO: your update code here
      self.rewards.append(new_reward)

# Helper function to combine a list of Memory objects into a single Memory.
#     This will be very useful for batching.
def aggregate_memories(memories):
  batch_memory = Memory()
  
  for memory in memories:
    for step in zip(memory.observations, memory.actions, memory.rewards):
      batch_memory.add_to_memory(*step)
  
  return batch_memory

# Instantiate a single Memory buffer
memory = Memory()

# %% [markdown]
# ## 3.3 Reward function
#
# We're almost ready to begin the learning algorithm for our agent! The next step is to compute the rewards of our agent as it acts in the environment. Since we (and the agent) is uncertain about if and when the game or task will end (i.e., when the pole will fall), it is useful to emphasize getting rewards **now** rather than later in the future -- this is the idea of discounting. This is a similar concept to discounting money in the case of interest. ecall from lecture, we use reward discount to give more preference at getting rewards now rather than later in the future. The idea of discounting rewards is similar to discounting money in the case of interest.
#
# To compute the expected cumulative reward, known as the **return**, at a given timestep in a learning episode, we sum the discounted rewards expected at that time step $t$, within a learning episode, and projecting into the future. We define the return (cumulative reward) at a time step $t$, $R_{t}$ as:
#
# >$R_{t}=\sum_{k=0}^\infty\gamma^kr_{t+k}$
#
# where  $0 < \gamma < 1$ is the discount factor and $r_{t}$ is the reward at time step $t$, and the index $k$ increments projection into the future within a single learning episode. Intuitively, you can think of this function as depreciating any rewards received at later time steps, which will force the agent prioritize getting rewards now. Since we can't extend episodes to infinity, in practice the computation will be limited to the number of timesteps in an episode -- after that the reward is assumed to be zero.
#
# Take note of the form of this sum -- we'll have to be clever about how we implement this function. Specifically, we'll need to initialize an array of zeros, with length of the number of time steps, and fill it with the real discounted reward values as we loop through the rewards from the episode, which will have been saved in the agents memory. What we ultimately care about is which actions are better relative to other actions taken in that episode -- so, we'll normalize our computed rewards, using the mean and standard deviation of the rewards across the learning episode.

# %%
### Reward function ###

# Helper function that normalizes an np.array x
def normalize(x):
  x -= np.mean(x)
  x /= np.std(x)
  return x.astype(np.float32)

# Compute normalized, discounted, cumulative rewards (i.e., return)
# Arguments:
#   rewards: reward at timesteps in episode
#   gamma: discounting factor
# Returns:
#   normalized discounted reward
def discount_rewards(rewards, gamma=0.95): 
  discounted_rewards = np.zeros_like(rewards)
  R = 0
  for t in reversed(range(0, len(rewards))):
      # update the total discounted reward
      R = R * gamma + rewards[t]
      discounted_rewards[t] = R
      
  return normalize(discounted_rewards)

# %% [markdown]
# ## 3.4 Learning algorithm
#
# Now we can start to define the learing algorithm which will be used to reinforce good behaviors of the agent and discourage bad behaviours. In this lab, we will focus on *policy gradient* methods which aim to **maximize** the likelihood of actions that result in large rewards. Equivalently, this means that we want to **minimize** the negative likelihood of these same actions. We achieve this by simply **scaling** the probabilities by their associated rewards -- effectively amplifying the likelihood of actions that resujlt in large rewards.
#
# Since the log function is monotonically increasing, this means that minimizing **negative likelihood** is equivalent to minimizing **negative log-likelihood**.  Recall that we can easily compute the negative log-likelihood of a discrete action by evaluting its [softmax cross entropy](https://www.tensorflow.org/api_docs/python/tf/nn/sparse_softmax_cross_entropy_with_logits). Like in supervised learning, we can use stochastic gradient descent methods to achieve the desired minimization.
#
# Let's begin by defining the loss function.

# %%
### Loss function ###

# Arguments:
#   logits: network's predictions for actions to take
#   actions: the actions the agent took in an episode
#   rewards: the rewards the agent received in an episode
# Returns:
#   loss
def compute_loss(logits, actions, rewards): 
  '''TODO: complete the function call to compute the negative log probabilities'''
  neg_logprob = tf.nn.sparse_softmax_cross_entropy_with_logits(
     logits=logits, labels=actions)
  
  '''TODO: scale the negative log probability by the rewards'''
  loss = tf.reduce_mean(neg_logprob * rewards)
  
  return loss

# %% [markdown]
# Now let's use the loss function to define a training step of our learning algorithm:

# %%
### Training step (forward and backpropagation) ###

def train_step(model, optimizer, observations, actions, discounted_rewards):
  with tf.GradientTape() as tape:
      # Forward propagate through the agent network
      logits = model(observations)

      '''TODO: call the compute_loss function to compute the loss'''
      loss = compute_loss(logits, actions, discounted_rewards)

  '''TODO: run backpropagation to minimize the loss using the tape.gradient method'''
  grads = tape.gradient(loss , model.trainable_variables)
  optimizer.apply_gradients(zip(grads, model.trainable_variables))

# %% [markdown]
# ## 3.5 Run cartpole!
#
# Having had no prior knowledge of the environment, the agent will begin to learn how to balance the pole on the cart based only on the feedback received from the environment! Having defined how our agent can move, how it takes in new observations, and how it updates its state, we'll see how it gradually learns a policy of actions to optimize balancing the pole as long as possible. To do this, we'll track how the rewards evolve as a function of training -- how should the rewards change as training progresses?

# %%
### Cartpole training! ###

# Learning rate and optimizer
learning_rate = 1e-3
optimizer = tf.keras.optimizers.Adam(learning_rate)

# instantiate cartpole agent
cartpole_model = create_cartpole_model()

# to track our progress
smoothed_reward = mdl.util.LossHistory(smoothing_factor=0.9)
plotter = mdl.util.PeriodicPlotter(sec=2, xlabel='Iterations', ylabel='Rewards')

if hasattr(tqdm, '_instances'): tqdm._instances.clear() # clear if it exists
for i_episode in range(500):

  plotter.plot(smoothed_reward.get())

  # Restart the environment
  observation = env.reset()
  memory.clear()

  while True:
      # using our observation, choose an action and take it in the environment
      action = choose_action(cartpole_model, observation)
      next_observation, reward, done, info = env.step(action)
      # add to memory
      memory.add_to_memory(observation, action, reward)
      
      # is the episode over? did you crash or do so well that you're done?
      if done:
          # determine total reward and keep a record of this
          total_reward = sum(memory.rewards)
          smoothed_reward.append(total_reward)
          
          # initiate training - remember we don't know anything about how the 
          #   agent is doing until it has crashed!
          train_step(cartpole_model, optimizer, 
                     observations=np.vstack(memory.observations),
                     actions=np.array(memory.actions),
                     discounted_rewards = discount_rewards(memory.rewards))
          
          # reset the memory
          memory.clear()
          break
      # update our observatons
      observation = next_observation

# %% [markdown]
# To get a sense of how our agent did, we can save a video of the trained model working on balancing the pole. Realize that this is a brand new environment that the agent has not seen before!
#
# Let's display the saved video to watch how our agent did!

# %%
saved_cartpole = mdl.lab3.save_video_of_model(cartpole_model, "CartPole-v0")
mdl.lab3.play_video(saved_cartpole)
# Out:
# Successfully saved 200 frames into CartPole-v0.mp4!
#         <video controls >
#             <source src="data:video/mp4;base64,..." type="video/mp4" />
#         </video>

# %% [markdown]
# How does the agent perform? Could you train it for shorter amounts of time and still perform well? Do you think that training longer would help even more?

# %% [markdown]
# #Part 2: Pong
#
# In Cartpole, we dealt with an environment that was static -- in other words, it didn't change over time. What happens if our environment is dynamic and unpredictable? Well that's exactly the case in [Pong](https://en.wikipedia.org/wiki/Pong), since part of the environment is the opposing player. We don't know how our opponent will act or react to our actions, so the complexity of our problem increases. It also becomes much more interesting, since we can compete to beat our opponent. RL provides a powerful framework for training AI systems with the ability to handle and interact with dynamic, unpredictable environments. In this part of the lab, we'll use the tools and workflow we explored in Part 1 to build an RL agent capable of playing the game of Pong.

# %% [markdown]
# ## 3.6 Define and inspect the Pong environment
#
# As with Cartpole, we'll instantiate the Pong environment in the OpenAI gym, using a seed of 1.

# %%
# !pip install atari-py
# !wget http://www.atarimania.com/roms/Roms.rar
# Out:
# Requirement already satisfied: atari-py in /usr/local/lib/python3.7/dist-packages (0.2.9)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from atari-py) (1.19.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from atari-py) (1.15.0)
# --2021-08-15 05:00:12--  http://www.atarimania.com/roms/Roms.rar
# Resolving www.atarimania.com (www.atarimania.com)... 195.154.81.199
# Connecting to www.atarimania.com (www.atarimania.com)|195.154.81.199|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11128004 (11M) [application/x-rar-compressed]
# Saving to: ‘Roms.rar’
#
# Roms.rar            100%[===================>]  10.61M   474KB/s    in 24s
#
# 2021-08-15 05:00:36 (457 KB/s) - ‘Roms.rar’ saved [11128004/11128004]

# %%
# !unrar x Roms.rar
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from Roms.rar
#
#   OK
#   OK
# All OK

# %%
# !unzip "HC ROMS.zip"
# Out:
# Archive:  HC ROMS.zip
#    creating: HC ROMS/
#    creating: HC ROMS/BY ALPHABET/
#    creating: HC ROMS/BY ALPHABET (PAL)/
#   inflating: HC ROMS/BY ALPHABET (PAL)/======== ROM HUNTER'S HARMONY CART PAL 1977-1992 VCS ROMS COLLECTION V4 ========.txt
#    creating: HC ROMS/BY ALPHABET (PAL)/A-G/
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/208 in 1 Game Select ROM (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/3-D Tic-Tac-Toe (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Acid Drop (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Action Man - Action Force (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Activision Decathlon, The (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Adventure (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Adventures on GX-12 (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Air Raid (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Air-Sea Battle (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Airlock (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Alpha Beam with Ernie (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Amidar (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Armor Ambush (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Artillery Duel (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Asterix (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Asteroid Fire (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Asteroids (PAL) [no copyright].bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Asteroids (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Astroblast (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Astrowar (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Atlantis (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Backgammon (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Bank Heist (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Barnstorming (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Base Attack (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Baseball (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Basic Math (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/BASIC Programming (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Basketball (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Battlezone (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Beamrider (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Beat 'Em & Eat 'Em (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Bermuda Triangle (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Berzerk (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Big Bird's Egg Catch (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Blackjack (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Blueprint (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/BMX Air Master (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Bobby Is Going Home (PAL) [demonstration cartridge].bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Bobby Is Going Home (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Bogey Blaster  (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Boing! (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Bowling (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Boxing (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Brain Games (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Breakout (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Bridge (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Buck Rogers - Planet of Zoom (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Bugs (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Bump 'n' Jump (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Bumper Bash (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Burning Desire (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Cakewalk (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/California Games (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Canyon Bomber (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Carnival (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Casino (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Centipede (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Centipede (Prototype) (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Challenge (HES) (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Challenge of.... Nexar, The (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Championship Soccer (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Checkers (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/China Syndrome (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Chopper Command (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Circus Atari (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Codebreaker (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Colors (Prototype) (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Combat (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Commando (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Commando Raid (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Communist Mutants from Space (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/CompuMate (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Condor Attack (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Congo Bongo (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Cookie Monster Munch (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Cosmic Ark (PAL) [selectable starfield].bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Cosmic Ark (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Cosmic Creeps (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Cosmic Swarm (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Cosmic War (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Crackpots (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Crash Dive (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Criminal Persuit (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Cross Force (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Crossbow (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Crystal Castles (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Custer's Revenge (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Dancing Plate (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Dark Chambers (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Deadly Discs (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Defender (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Demolition Herby (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Demon Attack (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Demons to Diamonds (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Der moderne Ritter (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Desert Falcon (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Diagnostic Test Cartridge 2.6P (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Dice Puzzle (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Dig Dug (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Dodge 'Em (PAL) [fixed].bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Dodge 'Em (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Donald Duck's Speedboat (Prototype) (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Donkey Kong (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Donkey Kong Junior (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Double Dragon (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Double Dunk (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Dragon Defender (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Dragonfire (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Dragonstomper (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Dragster (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Dumbo's Flying Circus (Prototype) (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/E.T. - The Extra-Terrestrial (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Earth Dies Screaming, The (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Eggomania (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Encounter at L-5 (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Enduro (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Escape from the Mindmaster (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Espial (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Euro Gen (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Exocet (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/F-14 Tomcat (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Fantastic Voyage (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Farmyard Fun (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Fast Food (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Fatal Run (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Fathom (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Fire Fighter (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Fireball (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Firebug (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Fishing Derby (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Flag Capture (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Flash Gordon (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Football (Atari) (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Football (Telegames) (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Forest (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Frankenstein's Monster (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Freeway (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Frisco (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Frog Demo (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Frogger (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Frogger II - Threeedeep! (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Frogs and Flies (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Frostbite (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Galaxian (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Gangster Alley (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Gas Hog (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Ghost Manor (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Ghostbusters (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Ghostbusters II (PAL) [different tune].bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Ghostbusters II (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Glacier Patrol (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Go Go Home Monster (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Golf (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Gopher (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Gorf (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Grand Prix (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/Gyruss (PAL).bin
#    creating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/128 in 1 Game Select ROM.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/3-D Genesis (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/3-D Ghost Attack (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/3-D Havoc (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/3-D Zapper (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Actionauts.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Alien.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Alligator People (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/AndroMan on the Moon (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Aquaventure (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Arkyology (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Atari VCS Point-of-Purchase ROM.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Atari Video Cube.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Atlantis II.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Atom Smasher (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Bachelor Party.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Beany Bopper.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Bear Game Demo.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Berenstain Bears.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Bionic Breakthrough.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Birthday Mania.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Boggle (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Bouncin' Baby Bunnies (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Bugs Bunny (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/BurgerTime.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Cabbage Patch Kids - Adventures in the Park (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Care Bears (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Cat Trax.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Cathouse Blues.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Chase the Chuck Wagon.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Coco Nuts.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Color Bar Generator.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Combat Two (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Computer Chess (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Confrontation (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Cosmic Commuter.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Crack'ed (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Crazy Climber.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Crypts of Chaos.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Cubicolor (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Deadly Duck.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Death Trap.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Depth Charge (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Diagnostic Test Cartridge 2.0 (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Diagnostic Test Cartridge 4.2.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Dolphin.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Dukes of Hazzard.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Dune (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Elevator Action (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Elf Adventure (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Eli's Ladder.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Elk Attack (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Entity, The (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Entombed.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Extra Terrestrials.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Final Approach.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Fire Fly.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Firefox (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Football Demo.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Frog Pond (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Front Line.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Funky Fish (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/GameLine Master Module ROM.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Gamma-Attack.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Garfield (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Gauntlet.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Glib - Video Word Game.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Going-Up (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Golf Diagnostic (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Good Luck, Charlie Brown (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Gravitar.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Gremlins.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Grover's Music Maker (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Guardian.bin
#    creating: HC ROMS/BY ALPHABET (PAL)/H-R/
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/H.E.R.O. (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Hangman (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Haunted House (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Homerun (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Human Cannonball (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Hunt & Score (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/I.Q. Memory Teaser  (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Ice Hockey (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Ikari Warriors (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Imagic Selector ROM (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Inca Gold (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Indy 500 (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Infernal Tower (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Infiltrate (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/International Soccer (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Jawbreaker (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Journey Escape (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Joust (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Jr. Pac-Man (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Jungle Hunt (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Kaboom! (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Kangaroo (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Karate (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Keystone Kapers (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Killer Satellites (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/King Kong (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Klax (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Knight on the Town (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Kung-Fu Master (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Laser Blast (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Laser Gates (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Lilly Adventure (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Lock 'n' Chase (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Los Angeles 1984 Games (Prototype) (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Lost Luggage (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/M.A.D. (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/M.A.S.H (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Mangia' (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Marauder (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Marine Wars (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Mario Bros. (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Master Builder (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Math Gran Prix (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Maze Craze - A Game of Cops 'n Robbers (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Mega Force (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/MegaMania - A Space Nightmare (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Midnight Magic (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Millipede (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Millipede (Prototype) (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Miner 2049er - Starring Bounty Bob (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Miner 2049er Volume II (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Mines of Minos (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Miniature Golf (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Missile Command (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Missile Control (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Mission 3,000 A.D. (PAL) [demonstration cartridge].bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Mission 3,000 A.D. (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Mission Survive (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Mole Hunter (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Moon Patrol (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Moonsweeper (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Motocross (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/MotoRodeo (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Mouse Trap (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Mr. Do! (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Mr. Postman (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Ms. Pac-Man (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/My Golf (PAL) [fixed].bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/My Golf (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Night Driver (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Night Stalker (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Nightmare (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/No Escape! (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Nuts (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Obelix (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Octopus (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Off the Wall (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Official Frogger, The (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Oink! (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Open, Sesame! (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Oscar's Trash Race (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Othello (PAL) [no grid markers].bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Othello (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Outlaw (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Pac-Man (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Panda Chase (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Parachute (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Party Mix - Bop a Buggy, Tug of War, Wizard's Keep, Down on the Line, Handcar (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Pengo (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Pete Rose Baseball (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Phantom Tank (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Pharaoh's Curse (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Phaser Patrol (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Phoenix (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Pick 'n' Pile (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Picnic (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Pigs in Space - Starring Miss Piggy (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Pitfall II - Lost Caverns (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Pitfall! (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Planet Patrol (PAL) [different spaceship].bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Planet Patrol (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Plaque Attack (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Polaris (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Pole Position (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Pooyan (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Popeye (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Pressure Cooker (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Private Eye (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Q-bert (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Quest for Quintana Roo (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Quick Step! (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Rabbit Transit (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Racing Car (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Racquetball (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Radar Lock (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Raft Rider (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Raiders of the Lost Ark (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Ram It (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Rampage! (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Reactor (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/RealSports Basketball (Prototype) (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/RealSports Boxing (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/RealSports Soccer (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/RealSports Tennis (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/RealSports Volleyball (PAL).bin
#    creating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Halloween.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Hard-Head (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Harem.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Heart Like a Wheel (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Holey Moley.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Ixion (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/James Bond 007.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Kabobber (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Kamikaze Saucers (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Kick-Man (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Kool-Aid Man.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Krull.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Kyphus (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Lasercade (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/London Blitz.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Looping (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Lord of the Rings, The - Journey to Rivendell (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/MagiCard.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Malagai.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Masters of the Universe - The Power of He-Man.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/McDonald's - Golden Arches Adventure (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/MegaBoy.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Meltdown (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Mind Maze (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Miss Piggy's Wedding (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Mogul Maniac.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Monster Cise (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Montezuma's Revenge - Featuring Panama Joe.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Morse Code Tutor.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Motocross Racer.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Mountain King.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Mr. Do!'s Castle.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Music Demo.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Music Machine, The.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Off Your Rocker (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Omega Race.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Out of Control.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Peek-A-Boo (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Pepsi Invaders.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Pick Up (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Piece o' Cake.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Pizza Chef (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Planet of the Apes (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/PlayAround Demo.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Pleiades (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Polo (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Pompeii (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Porky's.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Power Lords (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Pursuit of the Pink Panther (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Q-bert's Qubes.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Quadrun.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Racer (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/RealSports Baseball.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/RealSports Football.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Red Sea Crossing.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Rescue Terra I.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Revenge of the Beefsteak Tomatoes.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/River Patrol.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Rocky & Bullwinkle (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Rubik's Cube 3-D (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Rush Hour (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Riddle of the Sphinx (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/River Raid (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/River Raid II (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Road Runner (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Robin Hood (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Robot Tank (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Roc 'n Rope (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/H-R/Room of Doom (PAL).bin
#    creating: HC ROMS/BY ALPHABET (PAL)/S-Z/
#    creating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Saboteur (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Save the Whales (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Sea Battle.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Secret Agent (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Sentinel.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Shootin' Gallery.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Shuttle Orbiter.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Sinistar (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Sky Patrol (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Smurfs Save the Day.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Snow White (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Sorcerer.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Spitfire Attack.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Spy Hunter.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Squeeze Box.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Squoosh (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Star Fox.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Star Ship - Outer Space.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Stargunner.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Steeplechase.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Stellar Track.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Stone Age.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Stronghold.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Stunt Cycle (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Submarine Commander.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Supercharger BIOS.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Surf's Up (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Survival Run (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Survival Run.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Sweat! - The Decathlon Game (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Swordfight.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/SwordQuest - WaterWorld.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Tapper.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Tax Avoiders.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Telepathy (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Tempest (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Texas Chainsaw Massacre, The (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Texas Chainsaw Massacre, The.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Thwocker (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Time Pilot.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Tomarc the Barbarian.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Tooth Protectors.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Track and Field.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Tunnel Runner.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Turbo (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Unknown Activision Game (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Unknown Datatech Game.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Up 'n Down.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/VCS Draw Demo.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Venetian Blinds Demo.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Video Jogger.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Video Life [higher sounds].bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Video Life.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Video Reflex [no roman numbers].bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Video Reflex.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Wabbit.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Wall Ball.bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Wizard (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Xevious (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Zoo Keeper Sounds (Prototype).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/S.A.C. Alert (Prototype) (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Save Mary! (Prototype) (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Save Our Ship (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Sea Monster (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Seahawk (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Seaquest (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Seawolf 3 (Prototype) (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Secret Quest (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Shark Attack (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Shooting Arcade (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Sir Lancelot (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Skate Boardin' (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Skeet Shoot (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Ski Hunt (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Ski Run (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Skiing (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Skindiver (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Sky Alien (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Sky Diver (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Sky Jinks (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Sky Skipper (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Slot Machine (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Slot Racers (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Smurf (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Snail Against Squirrel (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Sneak 'n Peek (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Snoopy and the Red Baron (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Solar Fox (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Solar Storm (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Solaris (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Sorcerer's Apprentice (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Space Attack (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Space Cavern (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Space Invaders (PAL) [different speed and colors].bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Space Invaders (PAL) [fixed].bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Space Invaders (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Space Jockey (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Space Robot (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Space Shuttle - A Journey Into Space (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Space Tunnel (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Space War (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Spacechase (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/SpaceMaster X-7 (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Spectracube Invasion (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Spider Fighter (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Spider-Man (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Spike's Peak (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Springer (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Sprint Master (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Sssnake (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Stampede (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Star Raiders (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Star Strike (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Star Trek - Strategic Operations Simulator (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Star Voyager (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Star Wars - Jedi Arena (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Star Wars - Return of the Jedi - Death Star Battle (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Star Wars - Return of the Jedi - Ewok Adventure (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Star Wars - The Arcade Game (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Star Wars - The Empire Strikes Back (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Stargate (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/StarMaster (PAL) [fixed].bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/StarMaster (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Steeplechase (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Strategy X (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Strawberry Shortcake - Musical Match-Ups (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Street Racer (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Sub-Scan (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Subterranea (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Suicide Mission (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Summer Games (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Super Baseball (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Super Breakout (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Super Cobra (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Super Football (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Super Kung-Fu (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Supercharger BIOS (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Superman (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Surfer's Paradise - But Danger Below! (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Surround (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Survival Island (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Sword of Saros (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/SwordQuest - EarthWorld (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/SwordQuest - FireWorld (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Tac-Scan (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Tanks War (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Tapeworm (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Taz (Prototype) (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Teddy Apple (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Tennis (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Threshold (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Thunderground (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Time Warp (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Title Match Pro Wrestling (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Treasure Below (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Treasure Island (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Trick Shot (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Turmoil (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Tutankham (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/UFO Patrol (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Universal Chaos (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Vanguard (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Venture (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Video Checkers (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Video Chess (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Video Olympics (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Video Pinball (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Walker (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Wall Break (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Warlords (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Warplock (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Wing War (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Wings (Prototype) (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Winter Games (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Wizard of Wor (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Word Zapper (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Words-Attack (Prototype) (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/World End (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Worm War I (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/X-Man (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Xenophobe (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Yars' Revenge (PAL).bin
#   inflating: HC ROMS/BY ALPHABET (PAL)/S-Z/Zaxxon (PAL).bin
#   inflating: HC ROMS/BY ALPHABET/======== ROM HUNTER'S HARMONY CART ORIGINAL 1977-1992 VCS ROMS COLLECTION V11 ========.txt
#    creating: HC ROMS/BY ALPHABET/A-G/
# ...
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/RealSports Volleyball (1982) (Atari, Jim Huether, Alan J. Murphy, Robert C. Polaro) (CX2666, CX2666P) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Riddle of the Sphinx (1982) (Imagic, Rob Fulop, Bob Smith) (720106-2A, IA3600P, EIX-009-04I) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/River Raid - Jagdflieger (1982) (Activision, Carol Shaw - Ariola) (EAX-020, EAX-020-04B, EAX-020-04I - 711 020-720) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/River Raid II (1988) (Activision - Imagineering, Dan Kitchen, David Lubar) (EAK-048-04, EAK-048-04B) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Road Runner (1989) (Atari - Bobco, Robert C. Polaro) (CX2663) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Robin Hood (1983) (Xonox - K-Tel Software - Computer Magic) (99005, 6220, 6250) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Robot Tank - Rebellion der Roboter (Robotank) (1983) (Activision, Alan Miller - Ariola) (EAZ-028 - 711 028-725) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Roc 'n Rope (1984) (CBS Electronics, Ed English) (4L1751) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Room of Doom - Raum ohne Ausweg (1982) (CommaVid, Irwin Gaines - Ariola) (CM-004 - 712 004-720) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/S.A.C. Alert (Joyboard) (1983) (Amiga - Video Soft) (3135) (Prototype) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Save Mary! (Saving Mary) (10-24-1991) (Atari - Axlon, Tod Frye) (CX26178) (Prototype) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Seaquest - Rettung aus der Tiefe (1983) (Activision, Steve Cartwright - Ariola) (EAX-022, EAX-022-04I - 711 022-720) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Seawolf 3 (Submarine Commander Beta) (03-23-1981) (Sears Tele-Games, Marilyn Churchill, Matthew L. Hubbard) (CX2647 - 49-75142) (Prototype) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Secret Quest (1989) (Atari - Axlon, Steve DeFrisco) (CX26170, CX26170P) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Shark Attack (AKA Lochjaw) (1982) (Apollo - Games by Apollo, Steve Stringfellow) (AP-2005) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Shooting Arcade (Light Gun) (01-16-1990) (Atari - Axlon, Tod Frye - Heuristica, Agustin Ortiz) (CX26169) (Prototype) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Sir Lancelot (1983) (Xonox - K-Tel Software - Product Guild, Anthony R. Henderson) (99006, 6220) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Skate Boardin' (1987) (Absolute Entertainment, David Crane) (EAZ-042-04B, EAZ-042-04I) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Skeet Shoot (1981) (Apollo - Games by Apollo, Ed Salvo) (AP-1001) (PAL) (4K).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Skiing - Ski Weltcup (1980) (Activision, Bob Whitehead - Ariola) (EAG-005, PAG-005, EAG-005-04B - 711 005-715) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Sky Diver (1979) (Atari, Jim Huether) (CX2629, CX2629P) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Sky Jinks - Wettflug gegen die Zeit (1982) (Activision, Bob Whitehead - Ariola) (EAG-019, EAG-019-04I - 711 019-715) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Sky Skipper (1983) (Parker Brothers) (931510) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Slot Machine (1979) (Atari, David Crane) (CX2653P) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Slot Racers (1978) (Atari, Warren Robinett) (CX2606, CX2606P) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Smurf - Schtroumpfs - Pitufo (1983) (CBS Electronics - JWDA, Todd Marshall, Robin McDaniel, Henry Will IV) (4L1767, 4L1768, 4L1769, 4L1770) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Sneak 'n Peek - Der Unsichtbare (1983) (Carrere Video - JWDA, Garry Kitchen, Paul Willson - Teldec - Prism) (USC1002) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Snoopy and the Red Baron (1983) (Atari, Sam Comstock, Richard Dobbis, Nick 'Sandy Maiwald' Turner) (CX26111) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Solar Fox (1983) (CBS Electronics, Bob Curtiss) (4L1852, 4L1853, 4L1854, 4L1855) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Solar Storm (Paddle) (1983) (Imagic, Wilfredo Aguilar, Michael Becker, Dennis Koble) (720113-2A, 13206) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Solaris (The Last Starfighter, Star Raiders II, Universe) (1986) (Atari, Douglas Neubauer, Mimi Nyden) (CX26136) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Sorcerer's Apprentice (1983) (Atari, Jerome Domurat, Peter C. Niday, Robert Vieira) (CX26109) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Space Attack (1988) (Telegames) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Space Cavern - Les guerriers de l'espace (1982) (Apollo - Games by Apollo, Dan Oliver - RCA Video Jeux) (AP-2002) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Space Invaders (1980) (Atari, Richard Maurer) (CX2632, CX2632P) (PAL) [different speed and colors].bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Space Invaders (1980) (Atari, Richard Maurer) (CX2632, CX2632P) (PAL) [fixed].bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Space Invaders (1980) (Atari, Richard Maurer) (CX2632, CX2632P) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Space Jockey (1983) (Carrere Video - JWDA, Garry Kitchen - Teldec - Prism) (USC1001) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Space Robot (Dimax - Sinmax) (SM8001) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Space Shuttle - A Journey Into Space - Eine Reise ins All (1983) (Activision - Woodside Design Associates, Steve 'Jessica Stevens' Kitchen - Ariola) (EAZ-033 - 711 033-725) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Space War (1978) (Atari, Ian Shepard) (CX2604, CX2604P) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Spacechase (1982) (Apollo - Games by Apollo, Ed Salvo, Byron Parks) (AP-2001) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/SpaceMaster X-7 (208 in 1) (Unknown) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Spectracube Invasion (AKA Immies & Aggies) (1983) (Suntek) (SS-025) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Spider Fighter - Monster greifen an (1983) (Activision, Larry Miller - Ariola) (EAX-021, EAX-021-04I - 711 021-720) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Spider-Man (1982) (Parker Brothers, David Lamkins, Laura Nikolich) (931503) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Spike's Peak (1983) (Xonox - K-Tel Software - Beck-Tech, Steve Beck) (6210, 7210, 06003. 99001) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Springer (1983) (Tigervision - Software Electronics Corporation - Teldec) (7-006 - 3.60008 VG) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Sprint Master (Sprint 88, Sprint 2600) (1988) (Atari - Bobco, Robert C. Polaro) (CX26155P) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Sssnake (1983) (Gameworld) (133-003) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Stampede - Lasso-Helden (1981) (Activision, Bob Whitehead - Ariola) (EAG-011, PAG-011 - 711 011-715) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Star Raiders (Video Touch Pad) (1982) (Atari, Carla Meninsky) (CX2660) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Star Strike (1988) (Telegames) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Star Trek - Strategic Operations Simulator (1983) (SEGA, Jeff Lorenz - Teldec) (004-01) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Star Voyager (1982) (Imagic, Bob Smith) (720102-2B, IA3201P, EIX-011-04I) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Star Wars - Jedi Arena (Paddle) (1983) (Parker Brothers, Rex Bradford) (931507) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Star Wars - Return of the Jedi - Death Star Battle (Revenge of the Jedi - Game II) (1983) (Parker Brothers - JWDA, Todd Marshall, Robin McDaniel, Ray Miller) (931513) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Star Wars - Return of the Jedi - Ewok Adventure (Revenge of the Jedi - Game I) (1983) (Parker Brothers, Larry Gelberg) (PB5065) (Prototype) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Star Wars - The Arcade Game (1984) (Parker Brothers, Wilfredo Aguilar, Michael Becker, Neil McKenzie, Bob Smith, Brad Stewart) (PB5540) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Star Wars - The Empire Strikes Back (1982) (Parker Brothers, Rex Bradford, Sam Kjellman) (931501) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Stargate (1984) (Atari, Bill Aspromonte, Andrew Fuchs) (CX26120) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/StarMaster - Kommando Galaxis (1982) (Activision, Alan Miller - Ariola) (EAX-016, PAX-016 - 711 016-725) (PAL) [fixed].bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/StarMaster - Kommando Galaxis (1982) (Activision, Alan Miller - Ariola) (EAX-016, PAX-016 - 711 016-725) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Strategy X (1983) (Gakken) (010) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Strawberry Shortcake - Musical Match-Ups (1983) (Parker Brothers, Dawn Stockbridge) (PB5910) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Street Racer (Wheels) (Paddle) (1977) (Atari, Larry Kaplan) (CX2612, CX2612P) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Sub-Scan (Unknown) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Subterranea (Tarantula) (1983) (Imagic, Mark Klein) (EIZ-003-04I) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Suicide Mission (Meteoroids) (1982) (Starpath Corporation, Steve Hales, Stephen H. Landrum) (4) (AR-4102) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Summer Games (1987) (Epyx, Steven A. Baker, Tod Frye, Peter Engelbrite) (80561-00250) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Super Baseball (1988) (Atari, Mimi Nyden, Joseph Tung) (CX26152) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Super Breakout (Paddle) (1982 - 1981) (Atari, Carol Shaw, Nick 'Sandy Maiwald' Turner) (CX2608) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Super Cobra (1983) (Parker Brothers - Roklan, Paul Crowley, Bob Curtiss) (931505) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Super Football (1988) (Atari, Douglas Neubauer) (CX26154, CX26154P) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Super Kung-Fu (1983) (Xonox - K-Tel Software - VSS, Robert Weatherby) (6230, 6250) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Supercharger BIOS (1982) (Arcadia Corporation) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Superman (1979) (Atari, John Dunn) (CX2631, CX2631P) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Surround (1977) (Blockade) (Atari, Alan Miller) (CX2641, CX2641P) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Survival Island (Jungle Raid) (1983) (Starpath Corporation, Steve Mundry, Scott Nelson) (12) (AR-4401) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Sword of Saros (1983) (Starpath Corporation, Stephen H. Landrum, Jon Leupp) (11) (AR-4201) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/SwordQuest - EarthWorld (Adventure I, SwordQuest I - EarthWorld) (1982) (Atari, Dan Hitchens, Mimi Nyden) (CX2656) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/SwordQuest - FireWorld (Adventure II, SwordQuest II - FireWorld) (1983) (Atari, Tod Frye, Mimi Nyden) (CX2657) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Tac-Scan (Unknown) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Tapeworm (1982) (Spectravision - Spectravideo) (SA-204) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Taz (Tazz) (06-15-1983) (Atari, Jerome Domurat, Steve Woita) (CX2699) (Prototype) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Tennis (1981) (Activision, Alan Miller - Ariola) (EAG-007, EAG-007-04I, PAG-007 - 711 007-720) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Threshold (1982) (Tigervision, Warren Schwader - Teldec) (7-003) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Title Match Pro Wrestling - Pro Wrestling (1987) (Absolute Entertainment, Alex DeMeo) (EAZ-041-04I) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Trick Shot (1982) (Imagic, Dennis Koble) (720100-2B, IA3000P) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Turmoil (Unknown) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Tutankham (1983) (Parker Brothers, Dave Engman, Dawn Stockbridge) (931509) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/UFO Patrol (AKA X'Mission) (1983) (Suntek) (SS-031) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Universal Chaos (AKA Targ) (1988) (Telegames - VSS) (7062 A305) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Vanguard (1983) (Atari - GCC, Dave Payne) (CX2669, CX2669P) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Venture (1983) (CBS Electronics, Joseph Biel) (4L1802, 4L1803, 4L1804, 4L2278) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Video Checkers - Atari Video Checkers (1980) (Atari, Carol Shaw) (CX2636, CX2636P) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Video Chess (Computer Chess) (1979) (Atari, Larry Wagner, Bob Whitehead) (CX2645, CX2645P) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Video Olympics (Paddle) (1977) (Atari, Joe Decuir) (CX2621, CX2621P) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Video Pinball (1981) (Atari, Bob Smith) (CX2648) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Warlords (Kings in the Corner) (Paddle) (1981) (Atari, Carla Meninsky) (CX2610) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Warplock (Paddle) (1983) (Gameworld) (133-002) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Wings (10-10-1983) (CBS Electronics, Stuart Ross) (Prototype) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Winter Games (1987) (Epyx, Steven A. Baker, Tod Frye, Peter Engelbrite) (80561-00251) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Wizard of Wor (1982) (CBS Electronics - Roklan, Joe Hellesen, Joe Wagner) (4L1720, 4L1721, 4L1722, 4L2276) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Word Zapper (208 in 1) (Unknown) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Worm War I (208 in 1) (Unknown) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/X-Man (1983) (Universal Gamex Corporation, Miguel Castillo, H.K. Poon) (GX-001) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Xenophobe (1991) (Atari) (CX26172) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Yars' Revenge (Time Freeze) (1982) (Atari, Howard Scott Warshaw) (CX2655, CX2655P) (PAL).bin
#   inflating: HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Zaxxon (1983) (CBS Electronics) (4L1784, 4L1786, 4L1787, 4L2277) (PAL).bin

# %%
# !unzip ROMS.zip
# Out:
# Archive:  ROMS.zip
#    creating: ROMS/
#   inflating: ROMS/128 in 1 Game Select ROM (128 in 1) (Unknown) ~.bin
#   inflating: ROMS/2 Pak Special - Cavern Blaster, City War (1992) (HES) (773-867) (PAL).bin
#   inflating: ROMS/2 Pak Special - Challenge, Surfing (1990) (HES) (771-333) (PAL).bin
#   inflating: ROMS/2 Pak Special - Dolphin, Oink (1990) (HES) (771-341) (PAL).bin
#   inflating: ROMS/2 Pak Special - Dolphin, Pigs n' Wolf (1990) (HES) (771-341) (PAL).bin
#   inflating: ROMS/2 Pak Special - Dungeon Master, Creature Strike (1992) (HES) (773-891) (PAL).bin
#   inflating: ROMS/2 Pak Special - Hoppy, Alien Force (1992) (HES) (773-875) (PAL).bin
#   inflating: ROMS/2 Pak Special - Moto-Cross, Boom Bang (1990) (HES) (701-157) (PAL).bin
#   inflating: ROMS/2 Pak Special - Space Voyage, Fire Alert (1992) (HES) (773-883) (PAL).bin
#   inflating: ROMS/2 Pak Special - Star Warrior, Frogger (1990) (HES) (771-422) (PAL).bin
#   inflating: ROMS/2 Pak Special - Wall Defender, Planet Patrol (1990) (HES) (771-406) (PAL).bin
#   inflating: ROMS/208 in 1 Game Select ROM (208 in 1) (Unknown) (PAL) ~.bin
#   inflating: ROMS/3-D Genesis (1983) (Amiga - Video Soft, Jerry Lawson, Dan McElroy) (Prototype) ~.bin
#   inflating: ROMS/3-D Ghost Attack (1983) (Amiga - Video Soft, Michael K. Glass, Jerry Lawson) (Prototype) ~.bin
#   inflating: ROMS/3-D Havoc (1983) (Amiga - Video Soft, Frank Ellis, Jerry Lawson) (2110) (Prototype) ~.bin
#   inflating: ROMS/3-D Tic-Tac-Toe (1980) (Atari, Carol Shaw - Sears) (CX2618 - 49-75123) ~.bin
#   inflating: ROMS/3-D Tic-Tac-Toe (1980) (Atari, Carol Shaw) (CX2618, CX2618P) (PAL).bin
#   inflating: ROMS/3-D Zapper (12-15-82) (U.S. Games Corporation - JWDA, Todd Marshall) (Prototype) ~.bin
#   inflating: ROMS/3-D Zapper (U.S. Games Corporation - JWDA, Todd Marshall) (Prototype).bin
#   inflating: ROMS/32 in 1 Console ROM (02-10-1989) (Atari) (Prototype) (PAL).bin
#   inflating: ROMS/32 in 1 Game Cartridge (1988) (Atari) (CX26163P) (PAL).bin
#   inflating: ROMS/32 in 1 Game ROM (1988) (Atari) (Prototype) (PAL).bin
#   inflating: ROMS/3D Tic-Tac-Toe (32 in 1) (1988) (Atari, Carol Shaw) (CX26163P) (PAL).bin
#   inflating: ROMS/4 Game in One - Ice Hockey, Phantom UFO, Spy Vs. Spy, Cosmic Avenger (1983) (Bit Corporation) (PAL).bin
#   inflating: ROMS/4 Game in One - Rodeo Champ, Open Sesame, Bobby Is Going Home, Festival (1983) (Bit Corporation) (P460) (PAL).bin
#   inflating: ROMS/4 in 1 - Canyon Bomber, Home Run, Night Driver, Sky Diver (02-19-1987) (Atari) (CX26137) (Prototype).bin
#   inflating: ROMS/8 in 1 (Supergames 8 in 1) (01-16-92) (Atari) (CX26193) (Prototype).bin
#   inflating: ROMS/========  ROM HUNTER'S 1977-1992 VCS ROMS COLLECTION V16  ========.txt
#   inflating: ROMS/A-Team, The (AKA Saboteur) (03-30-1984) (Atari, Jerome Domurat, Howard Scott Warshaw) (CX26133) (Prototype).bin
#   inflating: ROMS/A-Team, The (AKA Saboteur) (05-08-1984) (Atari, Jerome Domurat, Howard Scott Warshaw) (CX26133) (Prototype).bin
#   inflating: ROMS/Acid Drop (1992) (Salu, Dennis M. Kiss) (460758) (PAL) ~.bin
#   inflating: ROMS/Action Man - Action Force (AKA G.I. Joe - Cobra Strike) (Paddle) (1983) (Parker Brothers, John Emerson) (931511) (PAL).bin
#   inflating: ROMS/Actionauts (Microbots) (1984-2008) (Imagic - Advanced Program Technology, Rob Fulop) ~.bin
#   inflating: ROMS/Activision Decathlon, The (1983) (Activision, David Crane) (AG-930-04, AZ-030) [fixed] ~.bin
#   inflating: ROMS/Activision Decathlon, The (1983) (Activision, David Crane) (AG-930-04, AZ-030) ~.bin
#   inflating: ROMS/Activision Decathlon, The (1983) (Activision, David Crane) (EAZ-030) (SECAM).bin
#   inflating: ROMS/Activision Decathlon, The - Zehnkampf (1983) (Activision, David Crane - Ariola) (EAZ-030, EAZ-030-04B, EAZ-030-04I - 711 030-725) (PAL).bin
#   inflating: ROMS/Adventure (1980) (Atari, Warren Robinett - Sears) (CX2613 - 49-75154) ~.bin
#   inflating: ROMS/Adventure (1980) (Atari, Warren Robinett) (CX2613, CX2613P) (PAL).bin
#   inflating: ROMS/Adventures of TRON (TRON Joystick) (1983) (M Network - INTV - APh Technological Consulting, Hal Finney, Glenn Hightower, Peter Kaminski) (MT4317) ~.bin
#   inflating: ROMS/Adventures on GX-12 (AKA Adventures of TRON) (1988) (Telegames) (4317 A009) (PAL).bin
#   inflating: ROMS/Air Raid (Men-A-Vision) (PAL) ~.bin
#   inflating: ROMS/Air Raiders (Air Battle) (1983) (M Network - INTV - APh Technological Consulting, Larry Zwick) (MT5861) ~.bin
#   inflating: ROMS/Air Raiders (Hack) (32 in 1) (Bit Corporation) (R320).bin
#   inflating: ROMS/Air Raiders (Unknown) (PAL).bin
#   inflating: ROMS/Air-Sea Battle (32 in 1) (1988) (Atari, Larry Kaplan) (CX26163P) (PAL).bin
#   inflating: ROMS/Air-Sea Battle (Hack) (Unknown) (4K).bin
#   inflating: ROMS/Air-Sea Battle - Air Sea Battle (Anti-Aircraft) (1977) (Atari, Larry Kaplan) (CX2602, CX2602P) (PAL).bin
#   inflating: ROMS/Air-Sea Battle - Air Sea Battle - Target Fun (Anti-Aircraft) (1977) (Atari, Larry Kaplan - Sears) (CX2602 - 99802, 6-99802, 49-75102) ~.bin
#   inflating: ROMS/Airlock (1982) (Data Age) (DA1004) (Prototype).bin
#   inflating: ROMS/Airlock (1982) (Data Age) (DA1004) ~.bin
#   inflating: ROMS/Airlock (1983) (Gameworld) (133-004) (PAL).bin
#   inflating: ROMS/Alices Abenteuer - Lilly Adventure (1983) (Quelle - Otto Versand) (732.273 8 - 600273, 781644) (PAL).bin
#   inflating: ROMS/Alien (1982) (20th Century Fox Video Games, Douglas 'Dallas North' Neubauer) (11006) ~.bin
#   inflating: ROMS/Alien (CCE).bin
#   inflating: ROMS/Alien's Return (AKA Go Go Home) (1983) (ITT Family Games) (554-33 391) (PAL).bin
#   inflating: ROMS/Alligator People (1983) (20th Century Fox Video Games, John Russell) (Prototype) ~.bin
#   inflating: ROMS/Alpha Beam with Ernie (Alpha Beam) (Kid's Controller) (06-03-1983) (Atari - CCW, Michael Callahan, Preston Stuart) (CX26103) (Prototype) (PAL).bin
#   inflating: ROMS/Alpha Beam with Ernie (Alpha Beam) (Kid's Controller) (12-22-1982) (Atari - CCW, Michael Callahan, Preston Stuart) (CX26103) (Prototype).bin
#   inflating: ROMS/Alpha Beam with Ernie (Alpha Beam) (Kid's Controller) (1983) (Atari - CCW, Michael Callahan, Preston Stuart) (CX26103) (PAL).bin
#   inflating: ROMS/Alpha Beam with Ernie (Alpha Beam) (Kid's Controller) (1983) (Atari - CCW, Michael Callahan, Preston Stuart) (CX26103) ~.bin
#   inflating: ROMS/Amidar (1982) (Parker Brothers, Ed Temple) (931504) (PAL).bin
#   inflating: ROMS/Amidar (1982) (Parker Brothers, Ed Temple) (PB5310) ~.bin
#   inflating: ROMS/Amidar (Hack) (32 in 1) (Bit Corporation) (R320).bin
#   inflating: ROMS/AndroMan on the Moon (1984) (Androbot - Western Technologies, Michael Case, Lenny Carlson) (Prototype) ~.bin
#   inflating: ROMS/Angeln I (AKA Fishing Derby) (Videospielkassette - Ariola) (PGP237) (PAL).bin
#   inflating: ROMS/Angriff der Luftflotten - Paris Attack (AKA M.A.D.) (1983) (Quelle - Otto Versand) (495.463 2 - 746381) (PAL).bin
#   inflating: ROMS/Ant Party (AKA Cosmic Swarm) (32 in 1) (1988) (Atari) (CX26163P) (PAL).bin
#   inflating: ROMS/Apples and Dolls (AKA Open, Sesame!) (CCE).bin
#   inflating: ROMS/Aquatak (AKA Skindiver) (1983) (John Sands Electronics) (JS145C) (PAL).bin
#   inflating: ROMS/Aquaventure (CCE).bin
#   inflating: ROMS/Aquaventure (Sea Sentinel) (08-12-1983) (Atari, Tod Frye, Gary Shannon) (Prototype) ~.bin
#   inflating: ROMS/Arkyology (1983) (Sparrow - Enter-Tech, Rick Harris, George Hefner, Paul Walters, Barbara Ultis) (Prototype) ~.bin
#   inflating: ROMS/Armor Ambush (1988) (Telegames) (PAL).bin
#   inflating: ROMS/Armor Ambush (Tank Battle) (1982) (M Network - INTV - APh Technological Consulting, Hal Finney) (MT5661) ~.bin
#   inflating: ROMS/Artillery Duel (1983) (Xonox - K-Tel Software - Action Graphics, Michael Schwartz, David Thiel) (6230, 7210, 06004, 99004) (PAL).bin
#   inflating: ROMS/Artillery Duel (1983) (Xonox - K-Tel Software - Action Graphics, Michael Schwartz, David Thiel) (6230, 7210, 06004, 99004) ~.bin
#   inflating: ROMS/Ases do Ar (AKA Sky Jinks) (Dismac).bin
#   inflating: ROMS/Assault (AKA Sky Alien) (1983) (Bomb - Onbase) (CA281) (PAL).bin
#   inflating: ROMS/Assault (AKA Sky Alien) (1983) (Bomb - Onbase) (CA281).bin
#   inflating: ROMS/Asterix (AKA Taz) (07-27-1983) (Atari, Jerome Domurat, Steve Woita) (CX2696) (Prototype).bin
#   inflating: ROMS/Asterix (AKA Taz) (1984) (Atari, Jerome Domurat, Steve Woita) (CX2696) (PAL).bin
#   inflating: ROMS/Asterix (AKA Taz) (1984) (Atari, Jerome Domurat, Steve Woita) (CX2696).bin
#   inflating: ROMS/Asteroid Belt (AKA Asteroid Fire) (1983) (Suntek) (SS-029) (PAL).bin
#   inflating: ROMS/Asteroid Fire (1983) (Home Vision - Gem International Corporation - VDI) (VCS83111) (PAL) ~.bin
#   inflating: ROMS/Asteroids (1981) (Atari, Brad Stewart - Sears) (CX2649 - 49-75163) [no copyright] ~.bin
#   inflating: ROMS/Asteroids (1981) (Atari, Brad Stewart - Sears) (CX2649 - 49-75163) ~.bin
#   inflating: ROMS/Asteroids (1981) (Atari, Brad Stewart) (CX2649, CX2649P) (PAL) [no copyright].bin
#   inflating: ROMS/Asteroids (1981) (Atari, Brad Stewart) (CX2649, CX2649P) (PAL).bin
#   inflating: ROMS/Astro Attack (AKA Time Warp) (1983) (Goliath - Hot Shot) (83-214) (PAL).bin
#   inflating: ROMS/Astroblast (Paddle) (1982) (M Network - INTV - APh Technological Consulting, Hal Finney) (MT5666) [fixed] ~.bin
#   inflating: ROMS/Astroblast (Paddle) (1982) (M Network - INTV - APh Technological Consulting, Hal Finney) (MT5666) ~.bin
#   inflating: ROMS/Astroblast (Paddle) (1988) (Telegames) (PAL).bin
#   inflating: ROMS/Astrowar (1983) (Goliath) (2) (PAL).bin
#   inflating: ROMS/Astrowar (Astrobattle) (Dimax - Sinmax) (SM8002) (PAL) ~.bin
#   inflating: ROMS/Astrowar (Unknown).bin
#   inflating: ROMS/Atari VCS Point-of-Purchase ROM (1982) (Atari) ~.bin
#   inflating: ROMS/Atari Video Cube (Atari Cube, Video Cube) (1983) (Atari - GCC) (CX2670) ~.bin
#   inflating: ROMS/Atlantis (1983) (CCE) (C-832) [a].bin
#   inflating: ROMS/Atlantis (1983) (CCE) (C-832).bin
#   inflating: ROMS/Atlantis (1983) (Digitel).bin
#   inflating: ROMS/Atlantis (1983) (Dynacom).bin
#   inflating: ROMS/Atlantis (Dactari - Milmar).bin
#   inflating: ROMS/Atlantis (Hack) (208 in 1) (Unknown) (PAL).bin
#   inflating: ROMS/Atlantis (Hack) (32 in 1) (Bit Corporation) (R320).bin
#   inflating: ROMS/Atlantis (Hack) (Unknown) (PAL).bin
#   inflating: ROMS/Atlantis (Lost City of Atlantis) (1982) (Imagic, Dennis Koble) (720103-1A, 720103-1B, IA3203, IX-010-04) ~.bin
#   inflating: ROMS/Atlantis (Lost City of Atlantis) (1982) (Imagic, Dennis Koble) (720103-2A, IA3203P, EIX-010-04I) (PAL).bin
#   inflating: ROMS/Atlantis II (1982) (Imagic, Dennis Koble) (720103-1A, IA3203).bin
#   inflating: ROMS/Atom Smasher (1984) (Video Soft) (Prototype) [stack pointer fix] ~.bin
#   inflating: ROMS/Atom Smasher (1984) (Video Soft) (Prototype).bin
#   inflating: ROMS/Aufruhr im Zoo (AKA Panda Chase) (1983) (Quelle) (719.694 2) (PAL).bin
#   inflating: ROMS/Autorennen (AKA Grand Prix) (Videospielkassette - Ariola) (PGP232) (PAL).bin
#   inflating: ROMS/Bachelor Party (Paddle) (1982) (Mystique - American Multiple Industries, Joel H. Martin) (1002) ~.bin
#   inflating: ROMS/Bachelor Party (Paddle) (1982) (PlayAround - J.H.M.) (205).bin
#   inflating: ROMS/Bachelorette Party (AKA Bachelor Party) (Paddle) (1982) (PlayAround - J.H.M.) (202).bin
#   inflating: ROMS/Backgammon (Paddle) (1979) (Atari, Craig Nelson - Sears) (CX2617 - 49-75183) ~.bin
#   inflating: ROMS/Backgammon (Paddle) (1979) (Atari, Craig Nelson) (CX2617, CX2617P) (PAL).bin
#   inflating: ROMS/Bank Heist (208 in 1) (Unknown) (PAL).bin
#   inflating: ROMS/Bank Heist (Action Hi-Tech - Hi-Score) (PAL).bin
#   inflating: ROMS/Bank Heist (Bonnie & Clyde, Cops 'n' Robbers, Hold-Up, Roaring 20's) (1983) (20th Century Fox Video Games, Bill Aspromonte) (11012) ~.bin
#   inflating: ROMS/Bank Heist (Hack) (32 in 1) (Bit Corporation) (R320).bin
#   inflating: ROMS/Barnstorming (1982) (Activision, Steve Cartwright) (AX-013) ~.bin
#   inflating: ROMS/Barnstorming (CCE).bin
#   inflating: ROMS/Barnstorming (Unknown) (PAL).bin
#   inflating: ROMS/Barnstorming - Die tollkeuhnen Flieger (1982) (Activision, Steve Cartwright - Ariola) (EAX-013, PAX-013 - 711 013-720) (PAL).bin
#   inflating: ROMS/Base Attack (1983) (Home Vision - Gem International Corporation - VDI) (VCS83113) (PAL) ~.bin
#   inflating: ROMS/Base Attack (Hack) (Unknown).bin
#   inflating: ROMS/Baseball (AKA Super Challenge Baseball) (1988) (Telegames) (5665 A016) (PAL).bin
#   inflating: ROMS/Baseball (AKA Super Challenge Baseball) (1988) (Telegames) (5665 A016).bin
#   inflating: ROMS/Basic Math (208 in 1) (Unknown) (PAL).bin
#   inflating: ROMS/Basic Math (Math Pack) (1977) (Atari, Gary Palmer) (CX2661) (PAL).bin
#   inflating: ROMS/Basic Math - Math (Math Pack) (1977) (Atari, Gary Palmer - Sears) (CX2661 - 99808, 6-99808) ~.bin
#   inflating: ROMS/BASIC Programming (Keyboard Controller) (1979) (Atari, Warren Robinett) (CX2620) ~.bin
#   inflating: ROMS/BASIC Programming (Keyboard Controller) (1979) (Atari, Warren Robinett) (CX2620, CX2620P) (PAL).bin
#   inflating: ROMS/Basketball (1978) (Atari, Alan Miller - Sears) (CX2624 - 6-99826, 49-75113) ~.bin
#   inflating: ROMS/Basketball (1978) (Atari, Alan Miller) (CX2624, CX2624P) (PAL).bin
#   inflating: ROMS/Basketball (208 in 1) (Unknown) (PAL).bin
#   inflating: ROMS/Basketball (32 in 1) (1988) (Atari, Alan Miller) (CX26163P) (PAL).bin
#   inflating: ROMS/Basketball (Hack) (208 in 1) (Unknown) (PAL).bin
#   inflating: ROMS/Basketball (Hack) (32 in 1) (Bit Corporation) (R320).bin
#   inflating: ROMS/Battlezone (05-02-1983) (Atari - GCC, Mike Feinstein, Brad Rice) (CX2681) (Prototype).bin
#   inflating: ROMS/Battlezone (05-12-1983) (Atari - GCC, Mike Feinstein, Brad Rice) (CX2681) (Prototype).bin
#   inflating: ROMS/Battlezone (1983) (Atari - GCC, Mike Feinstein, Brad Rice) (CX2681) ~.bin
#   inflating: ROMS/Battlezone (1983) (Atari - GCC, Mike Feinstein, Brad Rice) (CX2681, CX2681P) (PAL).bin
#   inflating: ROMS/Beamrider (1984) (Activision - Cheshire Engineering, David Rolfe, Larry Zwick) (AZ-037-04) ~.bin
#   inflating: ROMS/Beamrider (1984) (Activision - Cheshire Engineering, David Rolfe, Larry Zwick) (EAZ-037-04, EAZ-037-04I) (PAL).bin
#   inflating: ROMS/Beany Bopper (1982) (20th Century Fox Video Games - Sirius Software, Grady Ward) (11002) ~.bin
#   inflating: ROMS/Beany Bopper (1983) (CCE) (C-835).bin
#   inflating: ROMS/Bear Game Demo (1983) (SEGA, Fred Mack) ~.bin
#   inflating: ROMS/Beat 'Em & Eat 'Em (Paddle) (1982) (Mystique - American Multiple Industries, Joel H. Martin) (1003) ~.bin
#   inflating: ROMS/Beat 'Em & Eat 'Em (Paddle) (1982) (Mystique - American Multiple Industries, Joel H. Martin) (PAL).bin
#   inflating: ROMS/Beat 'Em & Eat 'Em (Paddle) (1982) (PlayAround - J.H.M.) (204).bin
#   inflating: ROMS/Beat 'Em & Eat 'Em (Paddle) (1983) (Dynacom).bin
#   inflating: ROMS/Berenstain Bears (Kid Vid Voice Module) (1983) (Coleco) (2658) ~.bin
#   inflating: ROMS/Bermuda (AKA River Raid) (1983) (Quelle) (322.913 5) (PAL).bin
#   inflating: ROMS/Bermuda (AKA River Raid) (Unknown) (PAL).bin
#   inflating: ROMS/Bermuda Triangle (1983) (Data Age, J. Ray Dettling) (112-007) ~.bin
#   inflating: ROMS/Bermuda Triangle (1983) (Gameworld, J. Ray Dettling) (133-007) (PAL).bin
#   inflating: ROMS/Bermuda, The (AKA River Raid) (1983) (Rainbow Vision - Suntek) (SS-009) (PAL) [a].bin
#   inflating: ROMS/Bermuda, The (AKA River Raid) (1983) (Rainbow Vision - Suntek) (SS-009) (PAL).bin
#   inflating: ROMS/Berzerk (1982) (Atari, Dan Hitchens - Sears) (CX2650 - 49-75168) ~.bin
#   inflating: ROMS/Berzerk (1982) (Atari, Dan Hitchens) (CX2650) (PAL).bin
#   inflating: ROMS/Berzerk (CCE).bin
#   inflating: ROMS/Berzerk (Unknown) (PAL) [a].bin
#   inflating: ROMS/Berzerk (Unknown) (PAL).bin
#   inflating: ROMS/Bi! Bi! (AKA Skindiver) (1983) (Rainbow Vision - Suntek) (SS-013) (PAL).bin
#   inflating: ROMS/Bi! Bi! (AKA Skindiver) (2600 Screen Search Console) (Jone Yuan Telephonic Enterprise Co) (PAL).bin
#   inflating: ROMS/Big Bird's Egg Catch (Grover's Egg Catch) (Kid's Controller) (05-02-1983) (Atari - CCW, Christopher H. Omarzu) (CX26104) (Prototype).bin
#   inflating: ROMS/Big Bird's Egg Catch (Grover's Egg Catch) (Kid's Controller) (05-17-1983) (Atari - CCW, Christopher H. Omarzu) (CX26104) (Prototype).bin
#   inflating: ROMS/Big Bird's Egg Catch (Grover's Egg Catch) (Kid's Controller) (12-08-1982) (Atari - CCW, Christopher H. Omarzu) (CX26104) (Prototype).bin
#   inflating: ROMS/Big Bird's Egg Catch (Grover's Egg Catch) (Kid's Controller) (1983) (Atari - CCW, Christopher H. Omarzu) (CX26104) (PAL).bin
#   inflating: ROMS/Big Bird's Egg Catch (Grover's Egg Catch) (Kid's Controller) (1983) (Atari - CCW, Christopher H. Omarzu) (CX26104) ~.bin
#   inflating: ROMS/Billard (AKA Trick Shot) (1983) (Quelle) (626.610 0) (PAL).bin
#   inflating: ROMS/Bingo (AKA Dice Puzzle) (1983) (CCE) (C-868) (PAL).bin
#   inflating: ROMS/Bionic Breakthrough (Headband - Super Breakout) (Mindlink Controller) (06-22-1984) (Atari, Paul Donaldson) (Prototype).bin
#   inflating: ROMS/Bionic Breakthrough (Headband - Super Breakout) (Mindlink Controller) (1984) (Atari, Paul Donaldson) (Prototype) ~.bin
#   inflating: ROMS/Birthday Mania (Paddle) (1984) (Personal Games Company, Robert Anthony Tokar) ~.bin
#   inflating: ROMS/Black Hole (AKA Cosmic Ark) (Double-Game Package) (1983) (Otto Versand) (311388) (PAL).bin
#   inflating: ROMS/Blackjack (32 in 1) (Paddle) (1988) (Atari, Bob Whitehead) (CX26163P) (PAL).bin
#   inflating: ROMS/Blackjack (Gambling) (Paddle) (1977) (Atari, Bob Whitehead) (CX2651) (PAL).bin
#   inflating: ROMS/Blackjack (Paddle) (Unknown) (PAL).bin
#   inflating: ROMS/Blackjack - Black Jack (Gambling) (Paddle) (1977) (Atari, Bob Whitehead - Sears) (CX2651 - 99805, 49-75602) ~.bin
#   inflating: ROMS/Bloody Human Freeway (Human Freeway) (Freeway Beta) (1981) (Activision, David Crane) (AG-009) (Prototype).bin
#   inflating: ROMS/Blueprint (1983) (CBS Electronics, Tom DiDomenico) (4L 2486 5000) (Prototype).bin
#   inflating: ROMS/Blueprint (1983) (CBS Electronics, Tom DiDomenico) (4L 2486 5000) ~.bin
#   inflating: ROMS/Blueprint (1983) (CBS Electronics, Tom DiDomenico) (4L2477, 4L2482, 4L2485, 4L4171) (PAL).bin
#   inflating: ROMS/BMX Air Master (1989) (Atari) (CX26190) (PAL).bin
#   inflating: ROMS/BMX Air Master (1989) (Atari) (CX26190).bin
#   inflating: ROMS/BMX Air Master (1989) (TNT Games - Sculptured Software, Adam Clayton) (26192) (PAL).bin
#   inflating: ROMS/BMX Air Master (1989) (TNT Games - Sculptured Software, Adam Clayton) (26192) ~.bin
#   inflating: ROMS/Bob Is Going Home (AKA Bobby Is Going Home) (JVP).bin
#   inflating: ROMS/Bobby geht nach Hause (AKA Bobby Is Going Home) (1983) (Quelle) (476.774 5) (PAL).bin
#   inflating: ROMS/Bobby Is Going Home (1983) (Bit Corporation) (PG206).bin
#   inflating: ROMS/Bobby Is Going Home (2600 Screen Search Console) (Jone Yuan Telephonic Enterprise Co).bin
#   inflating: ROMS/Bobby Is Going Home (Rentacom).bin
#   inflating: ROMS/Bobby Is Going Home - Bobby geht Heim (1983) (Bit Corporation) (PG206) (PAL) [demonstration cartridge].bin
#   inflating: ROMS/Bobby Is Going Home - Bobby geht Heim (1983) (Bit Corporation) (PG206) (PAL) ~.bin
#   inflating: ROMS/Bobby Is Going Home - Bobby Vai Para Casa (1983) (CCE) (C-803) (PAL).bin
#   inflating: ROMS/Bobby Is Going Home - Bobby Vai Para Casa (1983) (CCE) (C-803).bin
#   inflating: ROMS/Bogey Blaster (AKA Air Raiders) (1988) (Telegames) (5861 A030) (PAL).bin
#   inflating: ROMS/Bogey Blaster (AKA Air Raiders) (1988) (Telegames) (5861 A030).bin
#   inflating: ROMS/Boggle (08-07-1978) (Atari, David Crane) (Prototype) ~.bin
#   inflating: ROMS/Boing! (Bubbles, Soap Suds, The Emphysema Game) (1983) (First Star Software, Alex Leavens, Shirley Ann Russell) (PAL).bin
#   inflating: ROMS/Boing! (Bubbles, Soap Suds, The Emphysema Game) (1983) (First Star Software, Alex Leavens, Shirley Ann Russell) ~.bin
#   inflating: ROMS/Boom Bang (AKA Crackpots) (1983) (CCE) (C-849).bin
#   inflating: ROMS/Boom Bang (AKA Crackpots) (1983) (Rainbow Vision - Suntek) (SS-016) (PAL).bin
#   inflating: ROMS/Boom Bang (AKA Crackpots) (HES) (PAL).bin
#   inflating: ROMS/Boom Bang (AKA Crackpots) (Unknown) (PAL).bin
#   inflating: ROMS/Boom Bang (AKA Crackpots) (Unknown).bin
#   inflating: ROMS/Bouncin' Baby Bunnies (Baby Boom Boom, Bouncing Baby Monkeys) (1983) (Telesys, Alex Leavens) (Prototype) ~.bin
#   inflating: ROMS/Bowling (1979) (Atari, Larry Kaplan - Sears) (CX2628 - 6-99842, 49-75117) ~.bin
#   inflating: ROMS/Bowling (1979) (Atari, Larry Kaplan) (CX2628, CX2628P) (PAL).bin
#   inflating: ROMS/Bowling (208 in 1) (Unknown) (PAL).bin
#   inflating: ROMS/Bowling (32 in 1) (1988) (Atari, Larry Kaplan) (CX26163P) (PAL).bin
#   inflating: ROMS/Bowling (Dactar - Milmar).bin
#   inflating: ROMS/Bowling (Hack) (32 in 1) (Bit Corporation) (R320).bin
#   inflating: ROMS/Boxen (AKA Boxing) (Videospielkassette - Ariola) (PGP234) (PAL).bin
#   inflating: ROMS/Boxing (1983) (CCE) (C-861).bin
#   inflating: ROMS/Boxing (32 in 1) (1988) (Atari) (CX26163P) (PAL).bin
#   inflating: ROMS/Boxing (Dactari - Milmar).bin
#   inflating: ROMS/Boxing (Unknown) (PAL).bin
#   inflating: ROMS/Boxing - Box-Champion (1980) (Activision, Bob Whitehead - Ariola) (EAG-002, EAG-002-04I, PAG-002 - 711 002-715) (PAL).bin
#   inflating: ROMS/Boxing - La Boxe (1980) (Activision, Bob Whitehead) (AG-002, CAG-002, AG-002-04) ~.bin
#   inflating: ROMS/Brain Games (Keyboard Controller) (1978) (Atari, Larry Kaplan - Sears) (CX2664 - 6-99818) ~.bin
#   inflating: ROMS/Brain Games (Keyboard Controller) (1978) (Atari, Larry Kaplan) (CX2664, CX2664P) (PAL).bin
#   inflating: ROMS/Break-Down (AKA Wall Break) (1983) (Dynamics) (DY-192004) (PAL).bin
#   inflating: ROMS/Breakout (Paddle) (1978) (Atari, Brad Stewart) (CX2622, CX2622P) (PAL).bin
#   inflating: ROMS/Breakout - Breakaway IV (Paddle) (1978) (Atari, Brad Stewart - Sears) (CX2622 - 6-99813, 49-75107) ~.bin
#   inflating: ROMS/Bridge (1980) (Activision, Larry Kaplan - Ariola) (EAX-006, PAX-006 - 771 006-720) (PAL).bin
#   inflating: ROMS/Bridge (1980) (Activision, Larry Kaplan) (AX-006) [fixed] ~.bin
#   inflating: ROMS/Bridge (1980) (Activision, Larry Kaplan) (AX-006) ~.bin
#   inflating: ROMS/Bridge (208 in 1) (Unknown) (PAL).bin
#   inflating: ROMS/Buck Rogers - Planet of Zoom (1983) (SEGA - Teldec) (005-10) (PAL).bin
#   inflating: ROMS/Buck Rogers - Planet of Zoom (1983) (SEGA) (005-01) ~.bin
#   inflating: ROMS/Bugs (Paddle) (1982) (Data Age) (DA1005) ~.bin
#   inflating: ROMS/Bugs (Paddle) (1983) (Gameworld) (133-005) (PAL).bin
#   inflating: ROMS/Bugs Bunny (08-04-1983) (Atari, Alan J. Murphy, Robert C. Polaro) (CX26100) (Prototype) ~.bin
#   inflating: ROMS/Bugs Bunny (1983) (Atari, Alan J. Murphy, Robert C. Polaro) (CX26100) (Prototype).bin
#   inflating: ROMS/Bump 'n' Jump (1983) (M Network - INTV, David Akers, Joe King, Patricia Lewis Du Long, Jeff Ratcliff) (MT7045) ~.bin
#   inflating: ROMS/Bump 'n' Jump (1988) (Telegames) (7045 A015) (PAL).bin
#   inflating: ROMS/Bumper Bash (Paddle) (1983) (Spectravideo, David Lubar) (SA-218) ~.bin
#   inflating: ROMS/Bumper Bash (Paddle) (1983) (Spectravideo, David Lubar) (SA-218, SA-218C) (PAL).bin
#   inflating: ROMS/Bumper Bash (Unknown) (PAL).bin
#   inflating: ROMS/BurgerTime (1983) (M Network - INTV, Patricia Lewis Du Long, Ron Surratt) (MT4518) ~.bin
#   inflating: ROMS/Burning Desire (1982) (Mystique - American Multiple Industries) (1003) (PAL) ~.bin
#   inflating: ROMS/Burning Desire (1982) (PlayAround - J.H.M.) (202).bin
#   inflating: ROMS/Busy Police (AKA Keystone Kapers) (Funvision - Fund. International Co.).bin
#   inflating: ROMS/Busy Police (AKA Keystone Kapers) (Zellers).bin
#   inflating: ROMS/Cabbage Patch Kids - Adventures in the Park (05-24-1984) (Coleco - Individeo, Ed Temple) (Prototype).bin
#   inflating: ROMS/Cabbage Patch Kids - Adventures in the Park (06-14-1984) (Coleco - Individeo, Ed Temple) (Prototype).bin
#   inflating: ROMS/Cabbage Patch Kids - Adventures in the Park (06-XX-1984) (Coleco - Individeo, Ed Temple) (Prototype).bin
#   inflating: ROMS/Cabbage Patch Kids - Adventures in the Park (07-03-1984) (Coleco - Individeo, Ed Temple) (Prototype).bin
#   inflating: ROMS/Cabbage Patch Kids - Adventures in the Park (07-27-1984) (Coleco - Individeo, Ed Temple) (Prototype).bin
#   inflating: ROMS/Cabbage Patch Kids - Adventures in the Park (08-21-1984) (Coleco - Individeo, Ed Temple) (Prototype).bin
#   inflating: ROMS/Cabbage Patch Kids - Adventures in the Park (09-04-1984) (Coleco - Individeo, Ed Temple) (Prototype).bin
#   inflating: ROMS/Cabbage Patch Kids - Adventures in the Park (09-07-1984) (Coleco - Individeo, Ed Temple) (Prototype).bin
#   inflating: ROMS/Cabbage Patch Kids - Adventures in the Park (09-13-1984) (Coleco - Individeo, Ed Temple) (Prototype) [a].bin
#   inflating: ROMS/Cabbage Patch Kids - Adventures in the Park (09-13-1984) (Coleco - Individeo, Ed Temple) (Prototype) ~.bin
#   inflating: ROMS/Cakewalk (Bakery) (1983) (CommaVid, Irwin Gaines) (CM-008) ~.bin
#   inflating: ROMS/Cakewalk - Alarm in der Backstube (Bakery) (1983) (CommaVid, Irwin Gaines - Ariola) (CM-008 - 712 008-720) (PAL).bin
#   inflating: ROMS/California Games (1987) (Epyx, Steven A. Baker, Peter Engelbrite) (80561-00286) (PAL).bin
#   inflating: ROMS/California Games (1987) (Epyx, Steven A. Baker, Peter Engelbrite) (80561-00286) ~.bin
#   inflating: ROMS/Canyon Bomber (208 in 1) (Unknown) (PAL).bin
#   inflating: ROMS/Canyon Bomber (Paddle) (1979) (Atari, David Crane - Sears) (CX2607 - 6-99828, 49-75115) ~.bin
#   inflating: ROMS/Capture (AKA Wall Break) (1983) (Goliath - Hot Shot) (83-314) (PAL).bin
#   inflating: ROMS/Care Bears (1983) (Parker Brothers, Laura Nikolich) (Prototype) ~.bin
#   inflating: ROMS/Carnival (1982) (Coleco - Woodside Design Associates, Steve 'Jessica Stevens' Kitchen) (2468) ~.bin
#   inflating: ROMS/Carnival (1983) (CBS Electronics - Woodside Design Associates, Steve 'Jessica Stevens' Kitchen) (4L1717, 4L1718, 4L1719, 4L2277) (PAL).bin
#   inflating: ROMS/Carnival (Hack) (208 in 1) (Unknown) (PAL).bin
#   inflating: ROMS/Casino (Paddle) (1979) (Atari, Bob Whitehead) (CX2652, CX2652P) (PAL).bin
#   inflating: ROMS/Casino - Poker Plus (Paddle) (1979) (Atari, Bob Whitehead - Sears) (CX2652 - 6-99816, 49-75151) ~.bin
#   inflating: ROMS/Cat Trax (1983) (UA Limited) (1) [a].bin
#   inflating: ROMS/Cat Trax (1983) (UA Limited) (1) ~.bin
#   inflating: ROMS/Catch Time (AKA Plaque Attack) (1983) (Rainbow Vision - Suntek) (SS-015) (PAL).bin
#   inflating: ROMS/Catch Time (AKA Plaque Attack) (2600 Screen Search Console) (Jone Yuan Telephonic Enterprise Co).bin
#   inflating: ROMS/Catch Time (AKA Plaque Attack) (Video Game Cartridge - Ariola) (TP-602) (PAL).bin
#   inflating: ROMS/Cathouse Blues (1982) (PlayAround - J.H.M.) (201).bin
#   inflating: ROMS/Centipede (1982) (Atari - GCC) (CX2676) (Prototype) (PAL).bin
#   inflating: ROMS/Centipede (1983) (Atari - GCC) (CX2676) (PAL).bin
#   inflating: ROMS/Centipede (1983) (Atari - GCC) (CX2676) (Prototype).bin
#   inflating: ROMS/Centipede (1983) (Atari - GCC) (CX2676) ~.bin
#   inflating: ROMS/Challenge (208 in 1) (Unknown) (PAL).bin
#   inflating: ROMS/Challenge (HES) (PAL).bin
#   inflating: ROMS/Challenge (Unknown).bin
#   inflating: ROMS/Challenge (Zellers).bin
#   inflating: ROMS/Challenge of.... Nexar, The (1982) (Spectravision - Spectravideo - Sirius Software, David Lubar) (SA-206) (PAL).bin
#   inflating: ROMS/Challenge of.... Nexar, The (1982) (Spectravision - Spectravideo - Sirius Software, David Lubar) (SA-206) ~.bin
#   inflating: ROMS/Challenge of.... Nexar, The (Hack) (2600 Screen Search Console) (Jone Yuan Telephonic Enterprise Co).bin
#   inflating: ROMS/Challenge of.... Nexar, The (Unknown) (PAL).bin
#   inflating: ROMS/Championship Soccer (1980) (Atari, Steve Wright) (CX2616P) (PAL).bin
#   inflating: ROMS/Championship Soccer - Soccer (1980) (Atari, Steve Wright - Sears) (CX2616 - 49-75155) ~.bin
#   inflating: ROMS/Chase the Chuck Wagon (1983) (Spectravideo - TMQ Software - Video Games Industries Corporation, Michael Schwartz - Ralston Purina) ~.bin
#   inflating: ROMS/Checkers (1980) (Activision, Alan Miller) (AG-003) ~.bin
#   inflating: ROMS/Checkers (208 in 1) (Unknown) (PAL).bin
#   inflating: ROMS/Checkers (2600 Screen Search Console) (Jone Yuan Telephonic Enterprise Co).bin
#   inflating: ROMS/Checkers (32 in 1) (1988) (Atari) (CX26163P) (PAL).bin
#   inflating: ROMS/Cheese (Dragonfire Beta) (05-21-1982) (Imagic, Bob Smith) (720020-1A, IA3611) (Prototype).bin
#   inflating: ROMS/China Syndrome (1982) (Spectravision - Spectravideo) (SA-205) (PAL).bin
#   inflating: ROMS/China Syndrome (1982) (Spectravision - Spectravideo) (SA-205) ~.bin
#   inflating: ROMS/Chopper Command (1982) (Activision, Bob Whitehead) (AX-015, AX-015-04) ~.bin
#   inflating: ROMS/Chopper Command (1983) (CCE) (C-827) [a].bin
#   inflating: ROMS/Chopper Command (1983) (CCE) (C-827).bin
#   inflating: ROMS/Chopper Command (1983) (Digitel).bin
#   inflating: ROMS/Chopper Command (2600 Screen Search Console) (Jone Yuan Telephonic Enterprise Co).bin
#   inflating: ROMS/Chopper Command (Hack) (208 in 1) (Unknown) (PAL).bin
#   inflating: ROMS/Chopper Command (Hack) (2600 Screen Search Console) (Jone Yuan Telephonic Enterprise Co).bin
#   inflating: ROMS/Chopper Command (SuperVision) (405, 427, 806, 808, 813, 816) (PAL).bin
#   inflating: ROMS/Chopper Command - Captain Helicopter (1982) (Activision, Bob Whitehead - Ariola) (EAX-015, EAX-015-04I - 711 015-725) (PAL).bin
#   inflating: ROMS/Chuck Norris Superkicks (1983) (Xonox - K-Tel Software - VSS, Robert Weatherby) (6230, 06002, 06003, 99003) ~.bin
#   inflating: ROMS/Circus (AKA Circus Atari) (Zellers).bin
#   inflating: ROMS/Circus Atari (Hack) (32 in 1) (Bit Corporation) (R320).bin
#   inflating: ROMS/Circus Atari (Paddle) (1980) (Atari, Mike Lorenzen) (CX2630, CX2630P) (PAL).bin
#   inflating: ROMS/Circus Atari (Unknown) (PAL).bin
#   inflating: ROMS/Circus Atari (Unknown).bin
#   inflating: ROMS/Circus Atari - Circus (Paddle) (1980) (Atari, Mike Lorenzen - Sears) (CX2630 - 49-75122) ~.bin
#   inflating: ROMS/Coco Nuts (1982) (Telesys, Jim Rupp, Jack Woodman) (1001) ~.bin
#   inflating: ROMS/Codebreaker (Numbers) (Keyboard Controller) (1978) (Atari) (CX2643) (PAL).bin
#   inflating: ROMS/Codebreaker - Code Breaker (Numbers) (Keyboard Controller) (1978) (Atari - Sears) (CX2643 - 6-99815) ~.bin
#   inflating: ROMS/Color Bar Generator (1984) (Video Soft, Jerry Lawson, Dan McElroy) (VS1008) ~.bin
#   inflating: ROMS/Colors (1980) (Atari) (Prototype) (PAL) ~.bin
#   inflating: ROMS/Comando Suicida (AKA Chopper Command) (Dismac).bin
#   inflating: ROMS/Combat (32 in 1) (1988) (Atari, Joe Decuir, Larry Kaplan, Steve Mayer, Larry Wagner) (CX26163P) (PAL).bin
#   inflating: ROMS/Combat (Tank) (1977) (Atari, Joe Decuir, Larry Kaplan, Steve Mayer, Larry Wagner) (CX2601, CX2601P) (PAL).bin
#   inflating: ROMS/Combat - Tank-Plus (Tank) (1977) (Atari, Joe Decuir, Larry Kaplan, Steve Mayer, Larry Wagner - Sears) (CX2601 - 99801, 6-99801, 49-75101, 49-75124) ~.bin
#   inflating: ROMS/Combat Two (Super Combat) (1982) (Atari - GCC) (CX2663) (Prototype) ~.bin
#   inflating: ROMS/Commando (1988) (Activision - Imagineering, Mike Reidel) (AK-043-04) [different logo] ~.bin
#   inflating: ROMS/Commando (1988) (Activision - Imagineering, Mike Reidel) (AK-043-04) ~.bin
#   inflating: ROMS/Commando (1988) (Activision - Imagineering, Mike Reidel) (EAK-043-04I) (PAL).bin
#   inflating: ROMS/Commando Raid (1982) (U.S. Games Corporation - JWDA, Todd Marshall, Wes Trager, Henry Will IV) (VC1004) ~.bin
#   inflating: ROMS/Commando Raid (1983) (Carrere Video - JWDA, Todd Marshall, Wes Trager, Henry Will IV - Teldec - Prism) (USC1004) (PAL).bin
#   inflating: ROMS/Commando Raid (208 in 1) (Unknown) (PAL).bin
#   inflating: ROMS/Commando Raid (Unknown) (PAL).bin
#   inflating: ROMS/Communist Mutants from Space (Galactic Egg) (1982) (Arcadia Corporation, Stephen H. Landrum) (2) (AR-4101) ~.bin
#   inflating: ROMS/Communist Mutants from Space (Galactic Egg) (1982) (Starpath Corporation, Stephen H. Landrum) (2) (AR-4101) (PAL).bin
#   inflating: ROMS/Communist Mutants from Space (Galactic Egg) (Preview) (1982) (Arcadia Corporation, Stephen H. Landrum) (2) (AR-4101).bin
#   inflating: ROMS/Communist Mutants from Space (Galactic Egg) (Preview) (1982) (Starpath Corporation, Stephen H. Landrum) (2) (AR-4101) (PAL).bin
#   inflating: ROMS/CompuMate (1983) (Spectravideo - Universum) (SV-010) (PAL).bin
#   inflating: ROMS/CompuMate (1983) (Spectravideo) (SV-010) ~.bin
#   inflating: ROMS/Computer Chess (07-07-1978) (Atari, Larry Wagner, Bob Whitehead) (Prototype).bin
#   inflating: ROMS/Condor Attack (1982) (Ultravision) (1043) (PAL).bin
#   inflating: ROMS/Condor Attack (1982) (Ultravision) (1043) ~.bin
#   inflating: ROMS/Condor Attack (1983) (CCE) (C-851).bin
#   inflating: ROMS/Condor Attack (1983) (Goliath) (4) (PAL).bin
#   inflating: ROMS/Condor Attack (Action Hi-Tech - Hi-Score) (PAL).bin
#   inflating: ROMS/Condor Attack (Unknown) (PAL).bin
#   inflating: ROMS/Confrontation (1983) (Answer Software Corporation - TY Associates, Kim Ellis) (ASC2001) (Prototype) ~.bin
#   inflating: ROMS/Congo Bongo (1983) (SEGA - Beck-Tech, Steve Beck, Phat Ho - Teldec) (006-01 - 3.60105 VG) (PAL).bin
#   inflating: ROMS/Congo Bongo (1983) (SEGA - Beck-Tech, Steve Beck, Phat Ho) (006-01) [a].bin
#   inflating: ROMS/Congo Bongo (1983) (SEGA - Beck-Tech, Steve Beck, Phat Ho) (006-01) ~.bin
#   inflating: ROMS/Cookie Monster Munch (Cokie Monster's Maze, Cookie Monster's Garden) (Kid's Controller) (1983) (Atari - CCW, Gary Stark) (CX26102) (PAL) [a].bin
#   inflating: ROMS/Cookie Monster Munch (Cokie Monster's Maze, Cookie Monster's Garden) (Kid's Controller) (1983) (Atari - CCW, Gary Stark) (CX26102) (PAL).bin
#   inflating: ROMS/Cookie Monster Munch (Cokie Monster's Maze, Cookie Monster's Garden) (Kid's Controller) (1983) (Atari - CCW, Gary Stark) (CX26102) ~.bin
#   inflating: ROMS/Corrida da Matemаtica (AKA Math Gran Prix) (CCE).bin
#   inflating: ROMS/Cosmic Ark (1983) (CCE) (C-831) [a].bin
#   inflating: ROMS/Cosmic Ark (1983) (CCE) (C-831).bin
#   inflating: ROMS/Cosmic Ark (Canal 3 - Intellivision).bin
#   inflating: ROMS/Cosmic Ark (Reaction) (1982) (Imagic, Rob Fulop) (720104-1A, 720104-1B, IA3204) [selectable starfield] ~.bin
#   inflating: ROMS/Cosmic Ark (Reaction) (1982) (Imagic, Rob Fulop) (720104-1A, 720104-1B, IA3204) ~.bin
#   inflating: ROMS/Cosmic Ark (Reaction) (1982) (Imagic, Rob Fulop) (720104-2A, IA3204P, EIX-008-04I) (PAL) [selectable starfield].bin
#   inflating: ROMS/Cosmic Ark (Reaction) (1982) (Imagic, Rob Fulop) (720104-2A, IA3204P, EIX-008-04I) (PAL).bin
#   inflating: ROMS/Cosmic Ark (Unknown) (PAL).bin
#   inflating: ROMS/Cosmic Avenger (AKA StarMaster) (4 Game in One) (1983) (Bit Corporation) (PGP214) (PAL).bin
#   inflating: ROMS/Cosmic Commuter (1984) (Activision, John Van Ryzin) (AG-038-04) ~.bin
#   inflating: ROMS/Cosmic Commuter (CCE).bin
#   inflating: ROMS/Cosmic Corridor (AKA Space Tunnel) (1983) (ZiMAG - Emag - Vidco) (708-111 - GN-040).bin
#   inflating: ROMS/Cosmic Creeps (Space Maze, Spaze Maze) (1982) (Telesys, Don 'Donyo' Ruffcorn) (1002) (PAL).bin
#   inflating: ROMS/Cosmic Creeps (Space Maze, Spaze Maze) (1982) (Telesys, Don 'Donyo' Ruffcorn) (1002) ~.bin
#   inflating: ROMS/Cosmic Creeps (Unknown) (PAL).bin
#   inflating: ROMS/Cosmic Swarm (2600 Screen Search Console) (Jone Yuan Telephonic Enterprise Co).bin
#   inflating: ROMS/Cosmic Swarm (Termite) (1982) (CommaVid, John Bronstein) (CM-003) (Prototype).bin
#   inflating: ROMS/Cosmic Swarm (Termite) (1982) (CommaVid, John Bronstein) (CM-003) ~.bin
#   inflating: ROMS/Cosmic Swarm - Angriff der Termiten (Termite) (1982) (CommaVid, John Bronstein - Ariola) (CM-003 - 712 003-720) (PAL).bin
#   inflating: ROMS/Cosmic Town (AKA Base Attack) (Perry Rhodan-Serie) (1983) (ITT Family Games) (554-33 375) (PAL).bin
#   inflating: ROMS/Cosmic War (AKA Space Tunnel) (1983) (Home Vision - Gem International Corporation - VDI) (VCS83136) (PAL).bin
#   inflating: ROMS/Crack'ed (11-28-1988) (Atari - Zip Technology, Randy Bowker, Bruce Williams) (CX26142) (Prototype) ~.bin
#   inflating: ROMS/Crackpots (1983) (Activision, Dan Kitchen) (AX-029) ~.bin
#   inflating: ROMS/Crackpots (1983) (CCE) (C-862) [a].bin
#   inflating: ROMS/Crackpots (1983) (CCE) (C-862).bin
#   inflating: ROMS/Crackpots (2600 Screen Search Console) (Jone Yuan Telephonic Enterprise Co).bin
#   inflating: ROMS/Crackpots (Digivision).bin
#   inflating: ROMS/Crackpots (Unknown) (PAL).bin
#   inflating: ROMS/Crash Dive (Voyage to the Bottom of the Sea) (1983) (20th Century Fox Video Games, Bill Aspromonte) (11031) ~.bin
#   inflating: ROMS/Crash Dive (Voyage to the Bottom of the Sea) (1983) (20th Century Fox Video Games, Bill Aspromonte) (11131) (PAL).bin
#   inflating: ROMS/Crazy Climber (1983) (Atari - Roklan, Joe Gaucher, Alex Leavens) (CX2683) (Prototype) [a1].bin
#   inflating: ROMS/Crazy Climber (1983) (Atari - Roklan, Joe Gaucher, Alex Leavens) (CX2683) (Prototype) [a2].bin
#   inflating: ROMS/Crazy Climber (1983) (Atari - Roklan, Joe Gaucher, Alex Leavens) (CX2683) (Prototype) [a3].bin
#   inflating: ROMS/Crazy Climber (1983) (Atari - Roklan, Joe Gaucher, Alex Leavens) (CX2683) (Prototype).bin
#   inflating: ROMS/Crazy Climber (1983) (Atari - Roklan, Joe Gaucher, Alex Leavens) (CX2683) ~.bin
#   inflating: ROMS/Criminal Persuit (AKA A Mysterious Thief) (1983) (Suntek) (SS-036) (PAL).bin
#   inflating: ROMS/Criminal Pursuit (AKA A Mysterious Thief) (Video Game Cartridge - Ariola) (TP-619) (PAL).bin
#   inflating: ROMS/Cross Force (Cross Fire) (1982) (Spectravision - Spectravideo) (SA-203) ~.bin
#   inflating: ROMS/Cross Force (Unknown) (PAL) [a].bin
#   inflating: ROMS/Cross Force (Unknown) (PAL).bin
#   inflating: ROMS/Cross Force - Kreuzfeuer (Cross Fire) (1982) (Spectravision - Spectravideo - Quelle) (SA-203 - 413.223 9) (PAL).bin
#   inflating: ROMS/Crossbow (1988) (Atari - Imagineering, Dan Kitchen) (CX26139) ~.bin
#   inflating: ROMS/Crossbow (1988) (Atari - Imagineering, Dan Kitchen) (CX26139P) (PAL).bin
#   inflating: ROMS/Cruise Missile (AKA Exocet) (1987) (Froggo) (FG1007).bin
#   inflating: ROMS/Crypts of Chaos (1983) (20th Century Fox Video Games, John W.S. Marvin) (11009) ~.bin
#   inflating: ROMS/Crystal Castles (01-04-1984) (Atari, Michael Kosaka, Peter C. Niday, Robert Vieira) (CX26110) (Prototype).bin
#   inflating: ROMS/Crystal Castles (1984) (Atari, Michael Kosaka, Peter C. Niday, Robert Vieira) (CX26110) (PAL).bin
#   inflating: ROMS/Crystal Castles (1984) (Atari, Michael Kosaka, Peter C. Niday, Robert Vieira) (CX26110) ~.bin
#   inflating: ROMS/Cubicolor (1982) (Imagic, Rob Fulop) (Prototype) ~.bin
#   inflating: ROMS/Cubo Mаgico (AKA Cubicolor) (CCE).bin
#   inflating: ROMS/Curtiss (AKA Atlantis) (1983) (Rainbow Vision - Suntek) (SS-019) (PAL).bin
#   inflating: ROMS/Custer's Revenge (1982) (Mystique - American Multiple Industries, Joel H. Martin) (1001) ~.bin
#   inflating: ROMS/Custer's Revenge (1982) (Mystique - American Multiple Industries, Joel H. Martin) (PAL).bin
#   inflating: ROMS/Dancing Plate (1982) (Bit Corporation) (PG205).bin
#   inflating: ROMS/Dancing Plate (1982) (Puzzy - Bit Corporation) (PG205) (PAL).bin
#   inflating: ROMS/Dancing Plate (Unknown) (PAL).bin
#   inflating: ROMS/Dancing Plate - Dancing Plates - Tanzende Teller (1982) (Bit Corporation) (PG205) (PAL) ~.bin
#   inflating: ROMS/Dark Cavern (1982) (M Network - APh Technological Consulting, Hal Finney) (MT5667) ~.bin
#   inflating: ROMS/Dark Chambers (Dungeon, Dungeon Masters) (1988) (Atari - Sculptured Software, Adam Clayton) (CX26151, CX26151P) (Prototype) (PAL).bin
#   inflating: ROMS/Dark Chambers (Dungeon, Dungeon Masters) (1989) (Atari - Sculptured Software, Adam Clayton) (CX26151) ~.bin
#   inflating: ROMS/Dark Chambers (Dungeon, Dungeon Masters) (1989) (Atari - Sculptured Software, Adam Clayton) (CX26151, CX26151P) (PAL).bin
#   inflating: ROMS/Deadly Discs (AKA TRON - Deadly Discs) (1988) (Telegames) (PAL).bin
#   inflating: ROMS/Deadly Duck (1982) (20th Century Fox Video Games - Sirius Software, Ed Hodapp) (11004) ~.bin
#   inflating: ROMS/Death Trap (1983) (Avalon Hill, Jean Baer, Jim Jacob) (5001002) ~.bin
#   inflating: ROMS/Decathlon (AKA Activision Decathlon, The) (HES - Activision) (PAL) (16K).bin
#   inflating: ROMS/Defender (10-30-1981) (Atari, Robert C. Polaro, Alan J. Murphy - Sears) (CX2609 - 49-75186) (Prototype).bin
#   inflating: ROMS/Defender (1982) (Atari, Robert C. Polaro, Alan J. Murphy - Sears) (CX2609 - 49-75186) ~.bin
#   inflating: ROMS/Defender (1982) (Atari, Robert C. Polaro, Alan J. Murphy) (CX2609, CX2609P) (PAL).bin
#   inflating: ROMS/Defender (CCE).bin
#   inflating: ROMS/Defender (Dactari - Milmar).bin
#   inflating: ROMS/Defender (Digivision).bin
#   inflating: ROMS/Defender (Hack) (32 in 1) (Bit Corporation) (R320).bin
#   inflating: ROMS/Defender (Hack) (Unknown).bin
#   inflating: ROMS/Defender (Unknown) (PAL).bin
#   inflating: ROMS/Defender II (AKA Stargate) (1987) (Atari, Bill Aspromonte, Andrew Fuchs) (CX26120) (PAL).bin
#   inflating: ROMS/Defender II (AKA Stargate) (1987) (Atari, Bill Aspromonte, Andrew Fuchs) (CX26120).bin
#   inflating: ROMS/Demolition Herby (1983) (Telesys, Don Ruffcorn) (1006) (PAL).bin
#   inflating: ROMS/Demolition Herby (1983) (Telesys, Don Ruffcorn) (1006) ~.bin
#   inflating: ROMS/Demolition Herby (Unknown) (PAL).bin
#   inflating: ROMS/Demon Attack (1983) (CCE) (C-823).bin
#   inflating: ROMS/Demon Attack (Canal 3 - Intellivision) (C 3016).bin
#   inflating: ROMS/Demon Attack (Death from Above) (1982) (Imagic, Rob Fulop) (720000-200, 720101-1B, 720101-1C, IA3200, IA3200C, IX-006-04) [fixed] ~.bin
#   inflating: ROMS/Demon Attack (Death from Above) (1982) (Imagic, Rob Fulop) (720000-200, 720101-1B, 720101-1C, IA3200, IA3200C, IX-006-04) ~.bin
#   inflating: ROMS/Demon Attack (Death from Above) (1982) (Imagic, Rob Fulop) (720101-2B, IA3200P, EIX-006-04I) (PAL).bin
#   inflating: ROMS/Demon Attack (Hack) (32 in 1) (Bit Corporation) (R320).bin
#   inflating: ROMS/Demon Attack (Robby).bin
#   inflating: ROMS/Demon Attack (Supergame).bin
#   inflating: ROMS/Demon Attack (Unknown) (PAL).bin
#   inflating: ROMS/Demons to Diamonds (Hot Rox) (Paddle) (1982) (Atari, Alan J. Murphy, Nick 'Sandy Maiwald' Turner - Sears) (CX2615 - 49-75140) ~.bin
#   inflating: ROMS/Demons to Diamonds (Hot Rox) (Paddle) (1982) (Atari, Alan J. Murphy, Nick 'Sandy Maiwald' Turner) (CX2615) (PAL).bin
#   inflating: ROMS/Demons to Diamonds (Paddle) (CCE).bin
#   inflating: ROMS/Depth Charge (1983) (Amiga - Video Soft) (Prototype) ~.bin
#   inflating: ROMS/Der flinke Architekt (AKA Master Builder) (1983) (Quelle) (343.373 7) (PAL).bin
#   inflating: ROMS/Der Geheimkurier (AKA Mr. Postman) (1983) (Quelle) (802.744 3) (PAL).bin
#   inflating: ROMS/Der hungrige Panda - Panda (Quest) (AKA Panda Chase) (1983) (Quelle - Otto Versand) (731.662 3 - 550425) (PAL).bin
#   inflating: ROMS/Der kleine Baer (AKA Frostbite) (1983) (Quelle) (685.640 5) (PAL).bin
#   inflating: ROMS/Der moderne Ritter - Mr. T (AKA Fast Eddie) (1983) (Quelle - Otto Versand) (700.223 1 - 781627) (PAL).bin
#   inflating: ROMS/Der Vielfrass (AKA Fast Food) (1983) (Quelle) (176.543 7) (PAL).bin
#   inflating: ROMS/Desert Falcon (Nile Flyer, Sphinx) (05-27-1987) (Atari - Bobco, Robert C. Polaro) (CX26140, CX26140P) (Prototype) (PAL).bin
#   inflating: ROMS/Desert Falcon (Nile Flyer, Sphinx) (1987) (Atari - Bobco, Robert C. Polaro) (CX26140) ~.bin
#   inflating: ROMS/Desert Falcon (Nile Flyer, Sphinx) (1987) (Atari - Bobco, Robert C. Polaro) (CX26140, CX26140P) (PAL).bin
#   inflating: ROMS/Diagnostic Test Cartridge 2.0 (1980) (Atari) (50008) (Prototype) ~.bin
#   inflating: ROMS/Diagnostic Test Cartridge 2.6 (1982) (Atari) (MA017600) ~.bin
#   inflating: ROMS/Diagnostic Test Cartridge 2.6P (1982) (Atari) (TE016643) (PAL) (4K).bin
#   inflating: ROMS/Diagnostic Test Cartridge 4.2 (06-01-1982) (Atari) ~.bin
#   inflating: ROMS/Dice Puzzle (1983) (Panda) (106).bin
#   inflating: ROMS/Dice Puzzle (1983) (Sancho - Tang's Electronic Co.) (TEC005) (PAL) ~.bin
#   inflating: ROMS/Die Ente und der Wolf (AKA Pooyan) (1983) (Quelle) (688.383 9) (PAL).bin
#   inflating: ROMS/Die hungrigen Froesche (AKA Frogs and Flies) (1983) (Quelle) (043.151 0, 874.382 5) (PAL).bin
#   inflating: ROMS/Die Ratte und die Karotten (AKA Gopher) (1983) (Quelle) (687.463 0) (PAL).bin
#   inflating: ROMS/Die Springteufel (AKA Infiltrate) (1983) (Quelle) (176.654 2) (PAL).bin
#   inflating: ROMS/Die Unterwasser Bestien - Mariana (AKA Seaquest) (1983) (Quelle - Otto Versand) (463.734 4 - 550293) (PAL).bin
#   inflating: ROMS/Dig Dug (1983) (Atari - GCC, Douglas B. Macrae) (CX2677) ~.bin
#   inflating: ROMS/Dig Dug (1983) (Atari - GCC, Douglas B. Macrae) (CX2677, CX2677P) (PAL).bin
#   inflating: ROMS/Dishaster (AKA Dancing Plate) (1983) (ZiMAG - Emag - Vidco) (711-111 - GN-020).bin
#   inflating: ROMS/Dodge 'Em (Head On) (1980) (Atari, Carla Meninsky) (CX2637, CX2637P) (PAL) [fixed].bin
#   inflating: ROMS/Dodge 'Em (Head On) (1980) (Atari, Carla Meninsky) (CX2637, CX2637P) (PAL).bin
#   inflating: ROMS/Dodge 'Em (Unknown) (PAL).bin
#   inflating: ROMS/Dodge 'Em - Dodger Cars (Head On) (1980) (Atari, Carla Meninsky - Sears) (CX2637 - 49-75158) [fixed] ~.bin
#   inflating: ROMS/Dodge 'Em - Dodger Cars (Head On) (1980) (Atari, Carla Meninsky - Sears) (CX2637 - 49-75158) ~.bin
#   inflating: ROMS/Dolphin (1983) (Activision, Matthew L. Hubbard, Bob Whitehead) (AX-024) ~.bin
#   inflating: ROMS/Dolphin (CCE).bin
#   inflating: ROMS/Donald Duck's Speedboat (Donald Duck's Regatta) (04-12-1983) (Atari, Peter C. Niday) (CX26108) (Prototype) ~.bin
#   inflating: ROMS/Donald Duck's Speedboat (Donald Duck's Regatta) (04-18-1983) (Atari, Peter C. Niday) (CX26108) (Prototype) (PAL).bin
#   inflating: ROMS/Donkey Kong (1982) (Coleco - Woodside Design Associates - Imaginative Systems Software, Garry Kitchen) (2451) ~.bin
#   inflating: ROMS/Donkey Kong (1983) (CBS Electronics - Woodside Design Associates - Imaginative Systems Software, Garry Kitchen) (4L1700, 4L1701, 4L1702, 4L1802, 4L2274) (PAL).bin
#   inflating: ROMS/Donkey Kong (1983) (Pet Boat) (PAL).bin
#   inflating: ROMS/Donkey Kong (1987) (Atari) (CX26143).bin
#   inflating: ROMS/Donkey Kong (208 in 1) (Unknown) (PAL).bin
#   inflating: ROMS/Donkey Kong (AKA Inca Gold) (Star Game) (001).bin
#   inflating: ROMS/Donkey Kong (Hack) (32 in 1) (Bit Corporation) (R320).bin
#   inflating: ROMS/Donkey Kong Jr (AKA Donkey Kong Junior) (1983) (CCE) (C-1003).bin
#   inflating: ROMS/Donkey Kong Jr. (AKA Donkey Kong Junior) (Tron).bin
#   inflating: ROMS/Donkey Kong Junior (1983) (CBS Electronics - Woodside Design Associates, Harley H. Puthuff Jr.) (4L1802) (PAL).bin
#   inflating: ROMS/Donkey Kong Junior (1983) (Coleco - Woodside Design Associates, Harley H. Puthuff Jr.) (2653) ~.bin
#   inflating: ROMS/Donkey Kong Junior (1987) (Atari) (CX26144).bin
#   inflating: ROMS/Double Dragon (1989) (Activision - Imagineering, Donald Hahn, Dan Kitchen) (AK-050-04) ~.bin
#   inflating: ROMS/Double Dragon (1989) (Activision - Imagineering, Donald Hahn, Dan Kitchen) (EAK-050-04) (PAL).bin
#   inflating: ROMS/Double Dragon (CCE) (PAL).bin
#   inflating: ROMS/Double Dunk (Super Basketball) (1989) (Atari, Matthew L. Hubbard) (CX26159) (PAL).bin
#   inflating: ROMS/Double Dunk (Super Basketball) (1989) (Atari, Matthew L. Hubbard) (CX26159) ~.bin
#   inflating: ROMS/Dragon Defender (1983) (Suntek) (SS-021) (PAL) ~.bin
#   inflating: ROMS/Dragon Defender (Video Game Cartridge - Ariola) (TP-605) (PAL).bin
#   inflating: ROMS/Dragon Treasure (AKA Dragonfire) (Funvision - Fund. International Co.).bin
# ...
#   inflating: ROMS/Teddy Apple (AKA Open, Sesame!) (1983) (Home Vision - Gem International Corporation - VDI) (VCS83137) (PAL).bin
#   inflating: ROMS/Telepathy (Mindlink Controller) (1983) (Atari, Dan Oliver) (Prototype) ~.bin
#   inflating: ROMS/Teller-Jonglieren! (AKA Dancing Plate) (1983) (Quelle) (685.996 1) (PAL).bin
#   inflating: ROMS/Tempest (01-05-1984) (Atari, Michael Kosaka) (CX2687) (Prototype) ~.bin
#   inflating: ROMS/Tennis (1981) (Activision, Alan Miller - Ariola) (EAG-007, EAG-007-04I, PAG-007 - 711 007-720) (PAL).bin
#   inflating: ROMS/Tennis (1983) (CCE) (C-858) (4K).bin
#   inflating: ROMS/Tennis (2600 Screen Search Console) (Jone Yuan Telephonic Enterprise Co).bin
#   inflating: ROMS/Tennis (32 in 1) (1988) (Atari) (CX26163P) (PAL).bin
#   inflating: ROMS/Tennis (Canal 3 - Intellivision) (4K).bin
#   inflating: ROMS/Tennis (Dactari - Milmar).bin
#   inflating: ROMS/Tennis (Hack) (208 in 1) (Unknown) (PAL).bin
#   inflating: ROMS/Tennis (Hack) (32 in 1) (Bit Corporation) (R320).bin
#   inflating: ROMS/Tennis (Pet Boat) (PAL).bin
#   inflating: ROMS/Tennis (Star Game) (007).bin
#   inflating: ROMS/Tennis (Tennis Game) (AKA Tennis) (1983) (Home Vision - Gem International Corporation - VDI) (VCS83107) (PAL) (4K).bin
#   inflating: ROMS/Tennis (Unknown).bin
#   inflating: ROMS/Tennis (Zirok).bin
#   inflating: ROMS/Tennis - Le Tennis (1981) (Activision, Alan Miller) (AG-007, CAG-007) ~.bin
#   inflating: ROMS/Texas Chainsaw Massacre, The (1982) (Wizard Video Games, Bob Davis, Robert H. O'Neil) (Prototype) ~.bin
#   inflating: ROMS/Texas Chainsaw Massacre, The (1983) (Wizard Video Games - VSS, Ed Salvo) (008) ~.bin
#   inflating: ROMS/Threshold (1982) (Tigervision, Warren Schwader - Teldec) (7-003) (PAL).bin
#   inflating: ROMS/Threshold (1982) (Tigervision, Warren Schwader) (7-003) (Prototype).bin
#   inflating: ROMS/Threshold (1982) (Tigervision, Warren Schwader) (7-003) ~.bin
#   inflating: ROMS/Thunderground (Canal 3 - Intellivision).bin
#   inflating: ROMS/Thunderground (Underground) (1983) (SEGA, Jeff Lorenz) (003-01) ~.bin
#   inflating: ROMS/Thunderground (Unknown) (PAL).bin
#   inflating: ROMS/Thwocker (04-09-1984) (Activision, Charlie Heath) (Prototype) ~.bin
#   inflating: ROMS/Time Machine (AKA Asteroid Fire) (1983) (Goliath - Hot Shot) (83-112) (PAL).bin
#   inflating: ROMS/Time Pilot (1983) (Coleco - Woodside Design Associates, Harley H. Puthuff Jr.) (2663) ~.bin
#   inflating: ROMS/Time Pilot (Rentacom).bin
#   inflating: ROMS/Time Race (AKA Space Jockey) (1983) (Goliath - Hot Shot) (83-212) (PAL).bin
#   inflating: ROMS/Time Race (AKA Space Jockey) (1983) (Rainbow Vision - Suntek - Sunteck Corporation) (SS-001) (PAL).bin
#   inflating: ROMS/Time Race (AKA Time Warp) (Funvision - Fund. International Co.) (PAL).bin
#   inflating: ROMS/Time Warp (1982) (Funvision - Fund. International Co.) (PAL) ~.bin
#   inflating: ROMS/Time Warp (1982) (Funvision - Fund. International Co.).bin
#   inflating: ROMS/Time Warp (1983) (CCE) (C-845).bin
#   inflating: ROMS/Time Warp (Unknown) (PAL).bin
#   inflating: ROMS/Time Warp (Unknown).bin
#   inflating: ROMS/Time Warp (Zellers).bin
#   inflating: ROMS/Title Match Pro Wrestling (1987) (Absolute Entertainment, Alex DeMeo) (AG-041-04) ~.bin
#   inflating: ROMS/Title Match Pro Wrestling - Pro Wrestling (1987) (Absolute Entertainment, Alex DeMeo) (EAZ-041-04I) (PAL).bin
#   inflating: ROMS/Tom Boy (AKA Pitfall!) (1983) (Rainbow Vision - Suntek) (SS-005) (PAL).bin
#   inflating: ROMS/Tom Boy (AKA Pitfall!) (Unknown).bin
#   inflating: ROMS/Tom's Eierjagd (AKA Play Farm) (1983) (Quelle) (731.503 9) (PAL).bin
#   inflating: ROMS/Tomarc the Barbarian (Thundarr the Barbarian) (1983) (99007, 6240) (Xonox - K-Tel Software - Product Guild, Anthony R. Henderson) ~.bin
#   inflating: ROMS/Tomcat - The F-14 Fighter Simulator (1988) (Absolute Entertainment, Dan Kitchen) (AK-046-04) ~.bin
#   inflating: ROMS/Tooth Protectors (1983) (Camelot - DSD, Michael Doherty, Clyde Hager - Johnson & Johnson) ~.bin
#   inflating: ROMS/Top Gun - Air Patrol (AKA Air Raiders) (1983) (Quelle - Otto Versand) (626.502 9 - 746381) (PAL).bin
#   inflating: ROMS/Topy (2600 Screen Search Console) (Jone Yuan Telephonic Enterprise Co).bin
#   inflating: ROMS/Towering Inferno (1982) (U.S. Games Corporation - Western Technologies, Jeff Corsiglia, Paul Allen Newell, Tom Sloper) (VC1009) ~.bin
#   inflating: ROMS/Towering Inferno (208 in 1) (Unknown) (PAL).bin
#   inflating: ROMS/Track and Field (Los Angeles 1984 Games) (Track & Field Controller) (1984) (Atari - GCC, Jaques Hugon, Seth Lipkin) (CX26125, CX26127) ~.bin
#   inflating: ROMS/Treasure Below (1983) (Video Gems) (VG-05) (PAL) ~.bin
#   inflating: ROMS/Treasure Hunting (AKA Pitfall!) (Funvision - Fund. International Co.).bin
#   inflating: ROMS/Treasure Island (AKA Treasure Discovery) (1983) (Suntek) (SS-026) (PAL).bin
#   inflating: ROMS/Trick Shot (1982) (Imagic, Dennis Koble) (720000-100, 720100-1B, IA3000, IA3000C) ~.bin
#   inflating: ROMS/Trick Shot (1982) (Imagic, Dennis Koble) (720100-2B, IA3000P) (PAL).bin
#   inflating: ROMS/Trick Shot (Hack) (32 in 1) (Bit Corporation) (R320).bin
#   inflating: ROMS/TRON - Deadly Discs (TRON Joystick) (1983) (M Network - INTV - APh Technological Consulting, Jeff Ronne, Brett Stutz) (MT5662) ~.bin
#   inflating: ROMS/Tuby Bird (AKA Dolphin) (1983) (Rainbow Vision - Suntek) (SS-020) (PAL).bin
#   inflating: ROMS/Tuby Bird (AKA Dolphin) (208 in 1) (Unknown) (PAL).bin
#   inflating: ROMS/Tunnel Runner (Black Box) (1983) (CBS Electronics, Richard K. Balaska Jr., Andy Frank, Stuart Ross) (4L 2520 5000) (Prototype).bin
#   inflating: ROMS/Tunnel Runner (Black Box) (1983) (CBS Electronics, Richard K. Balaska Jr., Andy Frank, Stuart Ross) (4L 2520 5000) ~.bin
#   inflating: ROMS/Turbo (1982) (Coleco - Product Guild - GMA, Michael Green, Anthony R. Henderson, Gary Littleton) (2455) (Prototype) ~.bin
#   inflating: ROMS/Turmoil (1982) (20th Century Fox Video Games - Sirius Software, Mark Turmell) (11007) ~.bin
#   inflating: ROMS/Turmoil (Unknown) (PAL).bin
#   inflating: ROMS/Turmoil (Zellers).bin
#   inflating: ROMS/Turmoill (AKA Turmoil) (1983) (CCE) (C-850).bin
#   inflating: ROMS/Tutankham (1983) (Parker Brothers, Dave Engman, Dawn Stockbridge) (931509) (PAL).bin
#   inflating: ROMS/Tutankham (1983) (Parker Brothers, Dave Engman, Dawn Stockbridge) (PB5340) ~.bin
#   inflating: ROMS/UFI und sein gefaehrlicher Einsatz (AKA Go Go Home) (1983) (Quelle) (732.174 8) (PAL).bin
#   inflating: ROMS/UFO (AKA Space Jockey) (32 in 1) (1988) (Atari) (CX26163P) (PAL).bin
#   inflating: ROMS/UFO Patrol (AKA X'Mission) (1983) (Suntek) (SS-031) (PAL).bin
#   inflating: ROMS/Ungeheuer der Tiefe (AKA Skindiver) (1983) (Quelle) (719.013 5) (PAL).bin
#   inflating: ROMS/Universal Chaos (AKA Targ) (1988) (Telegames - VSS) (7062 A305) (PAL).bin
#   inflating: ROMS/Universal Chaos (AKA Targ) (1988) (Telegames - VSS) (7062 A305) (Prototype).bin
#   inflating: ROMS/Universal Chaos (AKA Targ) (1988) (Telegames - VSS) (7062 A305) ~.bin
#   inflating: ROMS/Unknown Activision Game (10-22-1982) (Activision) (Prototype).bin
#   inflating: ROMS/Unknown Activision Game (10-29-1982) (Activision) (Prototype) ~.bin
#   inflating: ROMS/Unknown Datatech Game (2600 Screen Search Console) (Jone Yuan Telephonic Enterprise Co) ~.bin
#   inflating: ROMS/Up 'n Down (1984) (SEGA - Beck-Tech, Steve Beck, Phat Ho) (009-01) ~.bin
#   inflating: ROMS/Vanguard (1982) (Atari - GCC, Dave Payne) (CX2669) (Prototype).bin
#   inflating: ROMS/Vanguard (1983) (Atari - GCC, Dave Payne) (CX2669) ~.bin
#   inflating: ROMS/Vanguard (1983) (Atari - GCC, Dave Payne) (CX2669, CX2669P) (PAL).bin
#   inflating: ROMS/Vanguard (CCE).bin
#   inflating: ROMS/Vanguard (Rentacom).bin
#   inflating: ROMS/Vanguard (VGS).bin
#   inflating: ROMS/VCS Draw Demo (Joe Gaucher) ~.bin
#   inflating: ROMS/Venetian Blinds Demo (1981) (Activision, David Crane, Bob Whitehead) ~.bin
#   inflating: ROMS/Venture (1982) (Coleco, Joseph Biel) (2457) (Prototype) (2K).bin
#   inflating: ROMS/Venture (1982) (Coleco, Joseph Biel) (2457) ~.bin
#   inflating: ROMS/Venture (1983) (CBS Electronics, Joseph Biel) (4L1802, 4L1803, 4L1804, 4L2278) (PAL).bin
#   inflating: ROMS/Venture (1987) (Atari) (CX26145).bin
#   inflating: ROMS/Viagem Espacial (AKA Star Voyager) (Dismac).bin
#   inflating: ROMS/Video Checkers - Atari Video Checkers (1980) (Atari, Carol Shaw) (CX2636, CX2636P) (PAL).bin
#   inflating: ROMS/Video Checkers - Checkers - Atari Video Checkers (1980) (Atari, Carol Shaw - Sears) (CX2636 - 49-75156) ~.bin
#   inflating: ROMS/Video Chess (Computer Chess) (1979) (Atari, Larry Wagner, Bob Whitehead - Sears) (CX2645 - 49-75181) ~.bin
#   inflating: ROMS/Video Chess (Computer Chess) (1979) (Atari, Larry Wagner, Bob Whitehead) (CX2645, CX2645P) (PAL).bin
#   inflating: ROMS/Video Chess (Unknown) (PAL).bin
#   inflating: ROMS/Video Jogger (Foot Craz) (1983) (Exus Corporation) ~.bin
#   inflating: ROMS/Video Life (1984) (CommaVid, John Bronstein) (CM-002) [higher sounds] ~.bin
#   inflating: ROMS/Video Life (1984) (CommaVid, John Bronstein) (CM-002) ~.bin
#   inflating: ROMS/Video Olympics (Paddle) (1977) (Atari, Joe Decuir) (CX2621, CX2621P) (PAL).bin
#   inflating: ROMS/Video Olympics - Pong Sports (Paddle) (1977) (Atari, Joe Decuir - Sears) (CX2621 - 99806, 6-99806, 49-75104) ~.bin
#   inflating: ROMS/Video Pinball (1981) (Atari, Bob Smith) (CX2648) (PAL).bin
#   inflating: ROMS/Video Pinball (Hack) (32 in 1) (Bit Corporation) (R320).bin
#   inflating: ROMS/Video Pinball (Unknown) (PAL).bin
#   inflating: ROMS/Video Pinball - Arcade Pinball (1981) (Atari, Bob Smith - Sears) (CX2648 - 49-75161) ~.bin
#   inflating: ROMS/Video Reflex (Foot Craz) (1983) (Exus Corporation) [no roman numbers] ~.bin
#   inflating: ROMS/Video Reflex (Foot Craz) (1983) (Exus Corporation) ~.bin
#   inflating: ROMS/Vogel Flieh (AKA Dolphin) (1983) (Quelle) (465.302 8) (PAL).bin
#   inflating: ROMS/Volleyball (AKA RealSports Volleyball) (1983) (Digitel).bin
#   inflating: ROMS/Volleyball (AKA RealSports Volleyball) (Dactari - Milmar).bin
#   inflating: ROMS/Volleyball (AKA RealSports Volleyball) (Double-Game Package) (1983) (Otto Versand) (781698) (PAL).bin
#   inflating: ROMS/Volleyball (AKA RealSports Volleyball) (Robby).bin
#   inflating: ROMS/Vom Himmel durch die Hoelle (AKA Parachute) (1983) (Quelle) (719.941 7) (PAL).bin
#   inflating: ROMS/Vulture Attack (AKA Condor Attack) (1982) (K-Tel Vision) (PAL).bin
#   inflating: ROMS/Vulture Attack (AKA Condor Attack) (1982) (K-Tel Vision).bin
#   inflating: ROMS/Vбdeo Cube (AKA Atari Video Cube) (CCE).bin
#   inflating: ROMS/Wabbit (1982) (Apollo, Ban Tran) (AP-2010) ~.bin
#   inflating: ROMS/Wachroboter jagt Jupy (AKA Keystone Kapers) (1983) (Quelle) (715.853 5) (PAL).bin
#   inflating: ROMS/Walker (1983) (Suntek) (SS-032) (PAL) [a].bin
#   inflating: ROMS/Walker (1983) (Suntek) (SS-032) (PAL) ~.bin
#   inflating: ROMS/Wall Ball (1983) (Avalon Hill, Duncan Scott) (5003002) ~.bin
#   inflating: ROMS/Wall Break (1983) (Home Vision - Gem International Corporation - VDI) (VCS83114) (PAL) ~.bin
#   inflating: ROMS/Wall Break (Unknown).bin
#   inflating: ROMS/Wall Defender (AKA Wall Break) (HES) (PAL).bin
#   inflating: ROMS/Wall-Defender (AKA Wall Break) (1983) (Bomb - Onbase) (CA285) (PAL).bin
#   inflating: ROMS/Wall-Defender (AKA Wall Break) (1983) (Bomb - Onbase) (CA285).bin
#   inflating: ROMS/War 2000 (AKA Astrowar) (1983) (Home Vision - Gem International Corporation - VDI) (VCS83102) (PAL).bin
#   inflating: ROMS/Warlords (Kings in the Corner) (Paddle) (1981) (Atari, Carla Meninsky - Sears) (CX2610 - 49-75127) ~.bin
#   inflating: ROMS/Warlords (Kings in the Corner) (Paddle) (1981) (Atari, Carla Meninsky) (CX2610) (PAL).bin
#   inflating: ROMS/Warplock (Paddle) (1982) (Data Age) (DA1002) ~.bin
#   inflating: ROMS/Warplock (Paddle) (1983) (Gameworld) (133-002) (PAL).bin
#   inflating: ROMS/Weltraumtunnel (AKA Innerspace) (1983) (Quelle) (292.651 7) (PAL).bin
#   inflating: ROMS/Westward Ho (AKA Custer's Revenge) (1982) (PlayAround - J.H.M.) (206) (PAL).bin
#   inflating: ROMS/Wilma Wanderer (AKA Lilly Adventure) (1983) (ITT Family Games) (PAL).bin
#   inflating: ROMS/Wing War (Flap!) (1983) (Imagic, Michael Greene) (EIZ-002-04I) (PAL) ~.bin
#   inflating: ROMS/Wings (06-03-1983) (CBS Electronics, Stuart Ross) (Prototype) ~.bin
#   inflating: ROMS/Wings (10-10-1983) (CBS Electronics, Stuart Ross) (Prototype) (PAL).bin
#   inflating: ROMS/Winter Games (1987) (Epyx, Steven A. Baker, Tod Frye, Peter Engelbrite) (80561-00251) (PAL).bin
#   inflating: ROMS/Winter Games (1987) (Epyx, Steven A. Baker, Tod Frye, Peter Engelbrite) (80561-00251) ~.bin
#   inflating: ROMS/Winterjagd (AKA Ski Hunt) (1983) (Quelle) (343.073 3) (PAL).bin
#   inflating: ROMS/Wizard (1980) (Atari, Chris Crawford) (Prototype) [a].bin
#   inflating: ROMS/Wizard (1980) (Atari, Chris Crawford) (Prototype) ~.bin
#   inflating: ROMS/Wizard of Wor (1982) (CBS Electronics - Roklan, Joe Hellesen, Joe Wagner) (4L1720, 4L1721, 4L1722, 4L2276) (PAL).bin
#   inflating: ROMS/Wizard of Wor (1982) (CBS Electronics - Roklan, Joe Hellesen, Joe Wagner) (M8774, M8794) (Prototype).bin
#   inflating: ROMS/Wizard of Wor (1982) (CBS Electronics - Roklan, Joe Hellesen, Joe Wagner) (M8774, M8794) ~.bin
#   inflating: ROMS/Word Zapper (208 in 1) (Unknown) (PAL).bin
#   inflating: ROMS/Word Zapper (Unknown) (PAL).bin
#   inflating: ROMS/Word Zapper (Unknown).bin
#   inflating: ROMS/Word Zapper (Word Grabber) (1982) (U.S. Games Corporation - Vidtec - JWDA, Todd Marshall, Henry Will IV) (VC1003) ~.bin
#   inflating: ROMS/Words-Attack (1983) (Sancho - Tang's Electronic Co.) (Prototype) (PAL) ~.bin
#   inflating: ROMS/World End (1983) (Home Vision - Gem International Corporation - VDI) (VCS83109) (PAL) ~.bin
#   inflating: ROMS/Worm War I (1982) (20th Century Fox Video Games - Sirius Software, David Lubar) (11001) ~.bin
#   inflating: ROMS/Worm War I (1983) (CCE) (C-843).bin
#   inflating: ROMS/Worm War I (208 in 1) (Unknown) (PAL).bin
#   inflating: ROMS/Worm War I (Unknown) (PAL).bin
#   inflating: ROMS/Wuestenschlacht (AKA Chopper Command) (1983) (Quelle) (262.794 1) (PAL).bin
#   inflating: ROMS/X'Mission (Unknown) (PAL).bin
#   inflating: ROMS/X-Man (1983) (Universal Gamex Corporation, Miguel Castillo, H.K. Poon) (GX-001) (PAL).bin
#   inflating: ROMS/X-Man (1983) (Universal Gamex Corporation, Miguel Castillo, H.K. Poon) (GX-001) ~.bin
#   inflating: ROMS/Xenophobe (1991) (Atari) (CX26172) (PAL).bin
#   inflating: ROMS/Xenophobe (1991) (Atari) (CX26172) ~.bin
#   inflating: ROMS/Xevious (01-18-1984) (Atari, Tod Frye) (CX2695) (Prototype) ~.bin
#   inflating: ROMS/Xevious (05-25-1983) (Atari, Tod Frye) (CX2695) (Prototype).bin
#   inflating: ROMS/Xevious (08-02-1983) (Atari, Tod Frye) (CX2695) (Prototype).bin
#   inflating: ROMS/Xevious (CCE).bin
#   inflating: ROMS/Yars' Revenge (Canal 3 - Intellivision).bin
#   inflating: ROMS/Yars' Revenge (Time Freeze) (09-01-81) (Atari, Howard Scott Warshaw - Sears) (CX2655 - 49-75167) (Prototype).bin
#   inflating: ROMS/Yars' Revenge (Time Freeze) (1982) (Atari, Howard Scott Warshaw - Sears) (CX2655 - 49-75167) ~.bin
#   inflating: ROMS/Yars' Revenge (Time Freeze) (1982) (Atari, Howard Scott Warshaw) (CX2655, CX2655P) (PAL).bin
#   inflating: ROMS/Year 1999, The (AKA Condor Attack) (1983) (Rainbow Vision - Suntek) (SS-008) (PAL).bin
#   inflating: ROMS/Z-Tack (AKA Base Attack) (1983) (Bomb - Onbase) (CA283) (PAL).bin
#   inflating: ROMS/Z-Tack (AKA Base Attack) (1983) (Bomb - Onbase) (CA283).bin
#   inflating: ROMS/Zaxxon (1983) (CBS Electronics) (4L1784, 4L1786, 4L1787, 4L2277) (PAL).bin
#   inflating: ROMS/Zaxxon (1983) (Coleco) (2454) ~.bin
#   inflating: ROMS/Zoo Fun (AKA Panda Chase) (1983) (Suntek) (SS-027) (PAL).bin
#   inflating: ROMS/Zoo Keeper Sounds (1984) (Atari, Christopher H. Omarzu, Robert Vieira) (CX26121) (Prototype) ~.bin

# %%
# !python -m atari_py.import_roms ./HC\ ROMS
# !python -m atari_py.import_roms ./ROMS
# Out:
# copying mr_do.bin from ./HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Mr. Do! (1983) (CBS Electronics, Ed English) (4L4478) (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/mr_do.bin
# copying king_kong.bin from ./HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/King Kong (1982) (Tigervision - Software Electronics Corporation, Karl T. Olinger - Teldec) (7-001 - 3.60001 VE) (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/king_kong.bin
# copying adventure.bin from ./HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Adventure (1980) (Atari, Warren Robinett) (CX2613, CX2613P) (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/adventure.bin
# copying keystone_kapers.bin from ./HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Keystone Kapers - Raueber und Gendarm (1983) (Activision, Garry Kitchen - Ariola) (EAX-025, EAX-025-04I - 711 025-725) (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/keystone_kapers.bin
# copying pacman.bin from ./HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Pac-Man (1982) (Atari, Tod Frye) (CX2646) (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/pacman.bin
# copying sir_lancelot.bin from ./HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Sir Lancelot (1983) (Xonox - K-Tel Software - Product Guild, Anthony R. Henderson) (99006, 6220) (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/sir_lancelot.bin
# copying laser_gates.bin from ./HC ROMS/PAL VERSIONS OF NTSC ORIGINALS/Laser Gates (AKA Innerspace) (1983) (Imagic, Dan Oliver) (720118-2A, 13208, EIX-007-04I) (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/laser_gates.bin
# copying up_n_down.bin from ./HC ROMS/BY COMPANY (PAL)/SEGA/REMAINING NTSC ORIGINALS/Up 'n Down.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/up_n_down.bin
# copying alien.bin from ./HC ROMS/BY COMPANY (PAL)/20th Century Fox Video Games/REMAINING NTSC ORIGINALS/Alien.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/alien.bin
# copying koolaid.bin from ./HC ROMS/BY COMPANY (PAL)/M Network - Mattel Electronics (NTSC ONLY)/Kool-Aid Man.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/koolaid.bin
# copying star_gunner.bin from ./HC ROMS/BY COMPANY (PAL)/Telesys/REMAINING NTSC ORIGINALS/Stargunner.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/star_gunner.bin
# copying air_raid.bin from ./HC ROMS/BY COMPANY (PAL)/Men-A-Vision/Air Raid (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/air_raid.bin
# copying gravitar.bin from ./HC ROMS/BY COMPANY (PAL)/Atari - Sears/REMAINING NTSC ORIGINALS/Gravitar.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/gravitar.bin
# copying krull.bin from ./HC ROMS/BY COMPANY (PAL)/Atari - Sears/REMAINING NTSC ORIGINALS/Krull.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/krull.bin
# copying elevator_action.bin from ./HC ROMS/BY COMPANY (PAL)/Atari - Sears/REMAINING NTSC ORIGINALS/Elevator Action (Prototype).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/elevator_action.bin
# copying crazy_climber.bin from ./HC ROMS/BY COMPANY (PAL)/Atari - Sears/REMAINING NTSC ORIGINALS/Crazy Climber.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/crazy_climber.bin
# copying montezuma_revenge.bin from ./HC ROMS/BY COMPANY (PAL)/Parker Brothers/REMAINING NTSC ORIGINALS/Montezuma's Revenge - Featuring Panama Joe.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/montezuma_revenge.bin
# copying jamesbond.bin from ./HC ROMS/BY COMPANY (PAL)/Parker Brothers/REMAINING NTSC ORIGINALS/James Bond 007.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/jamesbond.bin
# copying time_pilot.bin from ./HC ROMS/BY COMPANY (PAL)/Coleco (NTSC ONLY)/Time Pilot.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/time_pilot.bin
# copying space_invaders.bin from ./HC ROMS/BY ALPHABET/S-Z/Space Invaders.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/space_invaders.bin
# copying venture.bin from ./HC ROMS/BY ALPHABET/S-Z/Venture.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/venture.bin
# copying tennis.bin from ./HC ROMS/BY ALPHABET/S-Z/Tennis.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/tennis.bin
# copying trondead.bin from ./HC ROMS/BY ALPHABET/S-Z/TRON - Deadly Discs.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/trondead.bin
# copying skiing.bin from ./HC ROMS/BY ALPHABET/S-Z/Skiing.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/skiing.bin
# copying seaquest.bin from ./HC ROMS/BY ALPHABET/S-Z/Seaquest.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/seaquest.bin
# copying video_pinball.bin from ./HC ROMS/BY ALPHABET/S-Z/Video Pinball - Arcade Pinball.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/video_pinball.bin
# copying zaxxon.bin from ./HC ROMS/BY ALPHABET/S-Z/Zaxxon.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/zaxxon.bin
# copying surround.bin from ./HC ROMS/BY ALPHABET/S-Z/Surround - Chase.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/surround.bin
# copying tutankham.bin from ./HC ROMS/BY ALPHABET/S-Z/Tutankham.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/tutankham.bin
# copying yars_revenge.bin from ./HC ROMS/BY ALPHABET/S-Z/Yars' Revenge.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/yars_revenge.bin
# copying pong.bin from ./HC ROMS/BY ALPHABET/S-Z/Video Olympics - Pong Sports.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/pong.bin
# copying solaris.bin from ./HC ROMS/BY ALPHABET/S-Z/Solaris.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/solaris.bin
# copying wizard_of_wor.bin from ./HC ROMS/BY ALPHABET/S-Z/Wizard of Wor.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/wizard_of_wor.bin
# copying ms_pacman.bin from ./HC ROMS/BY ALPHABET/H-R/Ms. Pac-Man.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/ms_pacman.bin
# copying ice_hockey.bin from ./HC ROMS/BY ALPHABET/H-R/Ice Hockey.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/ice_hockey.bin
# copying phoenix.bin from ./HC ROMS/BY ALPHABET/H-R/Phoenix.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/phoenix.bin
# copying kangaroo.bin from ./HC ROMS/BY ALPHABET/H-R/Kangaroo.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/kangaroo.bin
# copying road_runner.bin from patched version of ./HC ROMS/BY ALPHABET/H-R/Road Runner.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/road_runner.bin
# copying journey_escape.bin from ./HC ROMS/BY ALPHABET/H-R/Journey Escape.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/journey_escape.bin
# copying pitfall.bin from ./HC ROMS/BY ALPHABET/H-R/Pitfall! - Pitfall Harry's Jungle Adventure.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/pitfall.bin
# copying riverraid.bin from ./HC ROMS/BY ALPHABET/H-R/River Raid.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/riverraid.bin
# copying hero.bin from ./HC ROMS/BY ALPHABET/H-R/H.E.R.O..bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/hero.bin
# copying kung_fu_master.bin from ./HC ROMS/BY ALPHABET/H-R/Kung-Fu Master.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/kung_fu_master.bin
# copying pooyan.bin from ./HC ROMS/BY ALPHABET/H-R/Pooyan.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/pooyan.bin
# copying kaboom.bin from ./HC ROMS/BY ALPHABET/H-R/Kaboom!.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/kaboom.bin
# copying qbert.bin from ./HC ROMS/BY ALPHABET/H-R/Q-bert.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/qbert.bin
# copying robotank.bin from ./HC ROMS/BY ALPHABET/H-R/Robot Tank.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/robotank.bin
# copying name_this_game.bin from ./HC ROMS/BY ALPHABET/H-R/Name This Game.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/name_this_game.bin
# copying private_eye.bin from ./HC ROMS/BY ALPHABET/H-R/Private Eye.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/private_eye.bin
# copying lost_luggage.bin from ./HC ROMS/BY ALPHABET/H-R/Lost Luggage [no opening scene].bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/lost_luggage.bin
# copying beam_rider.bin from ./HC ROMS/BY ALPHABET/A-G/Beamrider.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/beam_rider.bin
# copying breakout.bin from ./HC ROMS/BY ALPHABET/A-G/Breakout - Breakaway IV.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/breakout.bin
# copying double_dunk.bin from ./HC ROMS/BY ALPHABET/A-G/Double Dunk.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/double_dunk.bin
# copying battle_zone.bin from ./HC ROMS/BY ALPHABET/A-G/Battlezone.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/battle_zone.bin
# copying bowling.bin from ./HC ROMS/BY ALPHABET/A-G/Bowling.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/bowling.bin
# copying fishing_derby.bin from ./HC ROMS/BY ALPHABET/A-G/Fishing Derby.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/fishing_derby.bin
# copying donkey_kong.bin from ./HC ROMS/BY ALPHABET/A-G/Donkey Kong.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/donkey_kong.bin
# copying frostbite.bin from ./HC ROMS/BY ALPHABET/A-G/Frostbite.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/frostbite.bin
# copying carnival.bin from ./HC ROMS/BY ALPHABET/A-G/Carnival.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/carnival.bin
# copying galaxian.bin from ./HC ROMS/BY ALPHABET/A-G/Galaxian.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/galaxian.bin
# copying berzerk.bin from ./HC ROMS/BY ALPHABET/A-G/Berzerk.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/berzerk.bin
# copying centipede.bin from ./HC ROMS/BY ALPHABET/A-G/Centipede.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/centipede.bin
# copying amidar.bin from ./HC ROMS/BY ALPHABET/A-G/Amidar.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/amidar.bin
# copying bank_heist.bin from ./HC ROMS/BY ALPHABET/A-G/Bank Heist.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/bank_heist.bin
# copying atlantis.bin from ./HC ROMS/BY ALPHABET/A-G/Atlantis.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/atlantis.bin
# copying frogger.bin from ./HC ROMS/BY ALPHABET/A-G/Frogger.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/frogger.bin
# copying asteroids.bin from ./HC ROMS/BY ALPHABET/A-G/Asteroids [no copyright].bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/asteroids.bin
# copying gopher.bin from ./HC ROMS/BY ALPHABET/A-G/Gopher.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/gopher.bin
# copying demon_attack.bin from ./HC ROMS/BY ALPHABET/A-G/Demon Attack.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/demon_attack.bin
# copying chopper_command.bin from ./HC ROMS/BY ALPHABET/A-G/Chopper Command.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/chopper_command.bin
# copying enduro.bin from ./HC ROMS/BY ALPHABET/A-G/Enduro.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/enduro.bin
# copying boxing.bin from ./HC ROMS/BY ALPHABET/A-G/Boxing.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/boxing.bin
# copying freeway.bin from ./HC ROMS/BY ALPHABET/A-G/Freeway.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/freeway.bin
# copying defender.bin from ./HC ROMS/BY ALPHABET/A-G/Defender.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/defender.bin
# copying assault.bin from ./HC ROMS/NTSC VERSIONS OF PAL ORIGINALS/Assault (AKA Sky Alien) (1983) (Bomb - Onbase) (CA281).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/assault.bin
# copying asterix.bin from ./ROMS/Asterix (AKA Taz) (07-27-1983) (Atari, Jerome Domurat, Steve Woita) (CX2696) (Prototype).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/asterix.bin
# copying fishing_derby.bin from ./ROMS/Fishing Derby (1980) (Activision, David Crane) (AG-004) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/fishing_derby.bin
# copying tutankham.bin from ./ROMS/Tutankham (1983) (Parker Brothers, Dave Engman, Dawn Stockbridge) (PB5340) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/tutankham.bin
# copying road_runner.bin from patched version of ./ROMS/Road Runner (1989) (Atari - Bobco, Robert C. Polaro) (CX2663) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/road_runner.bin
# copying gravitar.bin from ./ROMS/Gravitar (1983) (Atari, Dan Hitchens, Mimi Nyden) (CX2685) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/gravitar.bin
# copying kaboom.bin from ./ROMS/Kaboom! (Paddle) (1981) (Activision, Larry Kaplan, David Crane) (AG-010, AG-010-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/kaboom.bin
# copying skiing.bin from ./ROMS/Skiing - Le Ski (1980) (Activision, Bob Whitehead) (AG-005, CAG-005, AG-005-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/skiing.bin
# copying wizard_of_wor.bin from ./ROMS/Wizard of Wor (1982) (CBS Electronics - Roklan, Joe Hellesen, Joe Wagner) (M8774, M8794) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/wizard_of_wor.bin
# copying qbert.bin from ./ROMS/Q-bert (1983) (Parker Brothers - Western Technologies, Dave Hampton, Tom Sloper) (PB5360) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/qbert.bin
# copying bank_heist.bin from ./ROMS/Bank Heist (Bonnie & Clyde, Cops 'n' Robbers, Hold-Up, Roaring 20's) (1983) (20th Century Fox Video Games, Bill Aspromonte) (11012) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/bank_heist.bin
# copying assault.bin from ./ROMS/Assault (AKA Sky Alien) (1983) (Bomb - Onbase) (CA281).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/assault.bin
# copying enduro.bin from ./ROMS/Enduro (1983) (Activision, Larry Miller) (AX-026, AX-026-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/enduro.bin
# copying breakout.bin from ./ROMS/Breakout - Breakaway IV (Paddle) (1978) (Atari, Brad Stewart - Sears) (CX2622 - 6-99813, 49-75107) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/breakout.bin
# copying phoenix.bin from ./ROMS/Phoenix (1983) (Atari - GCC, Mike Feinstein, John Mracek) (CX2673) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/phoenix.bin
# copying mr_do.bin from ./ROMS/Mr. Do! (1983) (CBS Electronics, Ed English) (4L4478) (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/mr_do.bin
# copying atlantis.bin from ./ROMS/Atlantis (Lost City of Atlantis) (1982) (Imagic, Dennis Koble) (720103-1A, 720103-1B, IA3203, IX-010-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/atlantis.bin
# copying donkey_kong.bin from ./ROMS/Donkey Kong (1982) (Coleco - Woodside Design Associates - Imaginative Systems Software, Garry Kitchen) (2451) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/donkey_kong.bin
# copying battle_zone.bin from ./ROMS/Battlezone (1983) (Atari - GCC, Mike Feinstein, Brad Rice) (CX2681) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/battle_zone.bin
# copying frostbite.bin from ./ROMS/Frostbite (1983) (Activision, Steve Cartwright) (AX-031) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/frostbite.bin
# copying centipede.bin from ./ROMS/Centipede (1983) (Atari - GCC) (CX2676) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/centipede.bin
# copying chopper_command.bin from ./ROMS/Chopper Command (1982) (Activision, Bob Whitehead) (AX-015, AX-015-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/chopper_command.bin
# copying tennis.bin from ./ROMS/Tennis - Le Tennis (1981) (Activision, Alan Miller) (AG-007, CAG-007) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/tennis.bin
# copying king_kong.bin from ./ROMS/King Kong (1982) (Tigervision - Software Electronics Corporation, Karl T. Olinger - Teldec) (7-001 - 3.60001 VE) (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/king_kong.bin
# copying freeway.bin from ./ROMS/Freeway (1981) (Activision, David Crane) (AG-009, AG-009-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/freeway.bin
# copying crazy_climber.bin from ./ROMS/Crazy Climber (1983) (Atari - Roklan, Joe Gaucher, Alex Leavens) (CX2683) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/crazy_climber.bin
# copying video_pinball.bin from ./ROMS/Pinball (AKA Video Pinball) (Zellers).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/video_pinball.bin
# copying riverraid.bin from ./ROMS/River Raid (1982) (Activision, Carol Shaw) (AX-020, AX-020-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/riverraid.bin
# copying star_gunner.bin from ./ROMS/Stargunner (1983) (Telesys, Alex Leavens) (1005) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/star_gunner.bin
# copying bowling.bin from ./ROMS/Bowling (1979) (Atari, Larry Kaplan - Sears) (CX2628 - 6-99842, 49-75117) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/bowling.bin
# copying frogger.bin from ./ROMS/Frogger (1982) (Parker Brothers, Ed English, David Lamkins) (PB5300) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/frogger.bin
# copying pooyan.bin from ./ROMS/Pooyan (1983) (Konami) (RC 100-X 02) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/pooyan.bin
# copying surround.bin from ./ROMS/Surround (32 in 1) (Bit Corporation) (R320).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/surround.bin
# copying lost_luggage.bin from ./ROMS/Lost Luggage (Airport Mayhem) (1982) (Apollo - Games by Apollo, Larry Minor, Ernie Runyon, Ed Salvo) (AP-2004) [no opening scene] ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/lost_luggage.bin
# copying galaxian.bin from ./ROMS/Galaxian (1983) (Atari - GCC, Mark Ackerman, Tom Calderwood, Glenn Parker) (CX2684) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/galaxian.bin
# copying krull.bin from ./ROMS/Krull (1983) (Atari, Jerome Domurat, Dave Staugas) (CX2682) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/krull.bin
# copying asteroids.bin from ./ROMS/Asteroids (1981) (Atari, Brad Stewart - Sears) (CX2649 - 49-75163) [no copyright] ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/asteroids.bin
# copying kung_fu_master.bin from ./ROMS/Kung-Fu Master (1987) (Activision - Imagineering, Dan Kitchen, Garry Kitchen) (AG-039-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/kung_fu_master.bin
# copying yars_revenge.bin from ./ROMS/Yars' Revenge (Time Freeze) (1982) (Atari, Howard Scott Warshaw - Sears) (CX2655 - 49-75167) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/yars_revenge.bin
# copying zaxxon.bin from ./ROMS/Zaxxon (1983) (Coleco) (2454) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/zaxxon.bin
# copying pitfall.bin from ./ROMS/Pitfall! - Pitfall Harry's Jungle Adventure (Jungle Runner) (1982) (Activision, David Crane) (AX-018, AX-018-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/pitfall.bin
# copying hero.bin from ./ROMS/H.E.R.O. (1984) (Activision, John Van Ryzin) (AZ-036-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/hero.bin
# copying adventure.bin from ./ROMS/Adventure (1980) (Atari, Warren Robinett) (CX2613, CX2613P) (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/adventure.bin
# copying seaquest.bin from ./ROMS/Seaquest (1983) (Activision, Steve Cartwright) (AX-022) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/seaquest.bin
# copying kangaroo.bin from ./ROMS/Kangaroo (1983) (Atari - GCC, Kevin Osborn) (CX2689) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/kangaroo.bin
# copying solaris.bin from ./ROMS/Solaris (The Last Starfighter, Star Raiders II, Universe) (1986) (Atari, Douglas Neubauer, Mimi Nyden) (CX26136) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/solaris.bin
# copying ms_pacman.bin from ./ROMS/Ms. Pac-Man (1983) (Atari - GCC, Mark Ackerman, Glenn Parker) (CX2675) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/ms_pacman.bin
# copying name_this_game.bin from ./ROMS/Name This Game (Guardians of Treasure) (1983) (U.S. Games Corporation - JWDA, Roger Booth, Sylvia Day, Ron Dubren, Todd Marshall, Robin McDaniel, Wes Trager, Henry Will IV) (VC1007) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/name_this_game.bin
# copying gopher.bin from ./ROMS/Gopher (Gopher Attack) (1982) (U.S. Games Corporation - JWDA, Sylvia Day, Todd Marshall, Robin McDaniel, Henry Will IV) (VC2001) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/gopher.bin
# copying keystone_kapers.bin from ./ROMS/Keystone Kapers - Raueber und Gendarm (1983) (Activision, Garry Kitchen - Ariola) (EAX-025, EAX-025-04I - 711 025-725) (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/keystone_kapers.bin
# copying demon_attack.bin from ./ROMS/Demon Attack (Death from Above) (1982) (Imagic, Rob Fulop) (720000-200, 720101-1B, 720101-1C, IA3200, IA3200C, IX-006-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/demon_attack.bin
# copying ice_hockey.bin from ./ROMS/Ice Hockey - Le Hockey Sur Glace (1981) (Activision, Alan Miller) (AX-012, CAX-012, AX-012-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/ice_hockey.bin
# copying pacman.bin from ./ROMS/Pac-Man (1982) (Atari, Tod Frye) (CX2646) (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/pacman.bin
# copying air_raid.bin from ./ROMS/Air Raid (Men-A-Vision) (PAL) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/air_raid.bin
# copying montezuma_revenge.bin from ./ROMS/Montezuma's Revenge - Featuring Panama Joe (1984) (Parker Brothers - JWDA, Henry Will IV) (PB5760) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/montezuma_revenge.bin
# copying amidar.bin from ./ROMS/Amidar (1982) (Parker Brothers, Ed Temple) (PB5310) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/amidar.bin
# copying trondead.bin from ./ROMS/TRON - Deadly Discs (TRON Joystick) (1983) (M Network - INTV - APh Technological Consulting, Jeff Ronne, Brett Stutz) (MT5662) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/trondead.bin
# copying defender.bin from ./ROMS/Defender (1982) (Atari, Robert C. Polaro, Alan J. Murphy - Sears) (CX2609 - 49-75186) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/defender.bin
# copying venture.bin from ./ROMS/Venture (1982) (Coleco, Joseph Biel) (2457) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/venture.bin
# copying double_dunk.bin from ./ROMS/Double Dunk (Super Basketball) (1989) (Atari, Matthew L. Hubbard) (CX26159) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/double_dunk.bin
# copying berzerk.bin from ./ROMS/Berzerk (1982) (Atari, Dan Hitchens - Sears) (CX2650 - 49-75168) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/berzerk.bin
# copying robotank.bin from ./ROMS/Robot Tank (Robotank) (1983) (Activision, Alan Miller) (AZ-028, AG-028-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/robotank.bin
# copying beam_rider.bin from ./ROMS/Beamrider (1984) (Activision - Cheshire Engineering, David Rolfe, Larry Zwick) (AZ-037-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/beam_rider.bin
# copying boxing.bin from ./ROMS/Boxing - La Boxe (1980) (Activision, Bob Whitehead) (AG-002, CAG-002, AG-002-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/boxing.bin
# copying private_eye.bin from ./ROMS/Private Eye (1984) (Activision, Bob Whitehead) (AG-034-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/private_eye.bin
# copying sir_lancelot.bin from ./ROMS/Sir Lancelot (1983) (Xonox - K-Tel Software - Product Guild, Anthony R. Henderson) (99006, 6220) (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/sir_lancelot.bin
# copying jamesbond.bin from ./ROMS/James Bond 007 (James Bond Agent 007) (1984) (Parker Brothers - On-Time Software, Joe Gaucher, Louis Marbel) (PB5110) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/jamesbond.bin
# copying up_n_down.bin from ./ROMS/Up 'n Down (1984) (SEGA - Beck-Tech, Steve Beck, Phat Ho) (009-01) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/up_n_down.bin
# copying elevator_action.bin from ./ROMS/Elevator Action (1983) (Atari, Dan Hitchens) (CX26126) (Prototype) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/elevator_action.bin
# copying journey_escape.bin from ./ROMS/Journey Escape (1983) (Data Age, J. Ray Dettling) (112-006) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/journey_escape.bin
# copying laser_gates.bin from ./ROMS/Laser Gates (AKA Innerspace) (1983) (Imagic, Dan Oliver) (720118-2A, 13208, EIX-007-04I) (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/laser_gates.bin
# copying koolaid.bin from ./ROMS/Kool-Aid Man (Kool Aid Pitcher Man) (1983) (M Network, Stephen Tatsumi, Jane Terjung - Kool Aid) (MT4648) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/koolaid.bin
# copying space_invaders.bin from ./ROMS/Space Invaders (1980) (Atari, Richard Maurer - Sears) (CX2632 - 49-75153) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/space_invaders.bin
# copying carnival.bin from ./ROMS/Carnival (1982) (Coleco - Woodside Design Associates, Steve 'Jessica Stevens' Kitchen) (2468) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/carnival.bin
# copying time_pilot.bin from ./ROMS/Time Pilot (1983) (Coleco - Woodside Design Associates, Harley H. Puthuff Jr.) (2663) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/time_pilot.bin
# copying alien.bin from ./ROMS/Alien (1982) (20th Century Fox Video Games, Douglas 'Dallas North' Neubauer) (11006) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/alien.bin
# copying pong.bin from ./ROMS/Video Olympics - Pong Sports (Paddle) (1977) (Atari, Joe Decuir - Sears) (CX2621 - 99806, 6-99806, 49-75104) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/pong.bin

# %%
def create_pong_env(): 
  return gym.make("Pong-v0", frameskip=5)
env = create_pong_env()
env.seed(1); # for reproducibility

# %% [markdown]
# Let's next consider the observation space for the Pong environment. Instead of four physical descriptors of the cart-pole setup, in the case of Pong our observations are the individual video frames (i.e., images) that depict the state of the board. Thus, the observations are 210x160 RGB images (arrays of shape (210,160,3)).
#
# We can again confirm the size of the observation space by query:

# %%
print("Environment has observation space =", env.observation_space)
# Out:
# Environment has observation space = Box(0, 255, (210, 160, 3), uint8)

# %% [markdown]
# In Pong, at every time step, the agent (which controls the paddle) has six actions to choose from: no-op (no operation), move right, move left, fire, fire right, and fire left. Let's confirm the size of the action space by querying the environment:

# %%
n_actions = env.action_space.n
print("Number of possible actions that the agent can choose from =", n_actions)
# Out:
# Number of possible actions that the agent can choose from = 6

# %% [markdown]
# ## 3.7 Define the Pong agent
#
# As before, we'll use a neural network to define our agent. What network architecture do you think would be especially well suited to this game? Since our observations are now in the form of images, we'll add convolutional layers to the network to increase the learning capacity of our network. Note that you will be tasked with completing a template CNN architecture for the Pong agent -- but you should certainly experiment beyond this template to try to optimize performance!

# %%
### Define the Pong agent ###

# Functionally define layers for convenience
# All convolutional layers will have ReLu activation
Conv2D = functools.partial(tf.keras.layers.Conv2D, padding='same', activation='relu')
Flatten = tf.keras.layers.Flatten
Dense = tf.keras.layers.Dense

# Defines a CNN for the Pong agent
def create_pong_model():
  model = tf.keras.models.Sequential([
    # Convolutional layers
    # First, 32 5x5 filters and 2x2 stride
    Conv2D(filters=32, kernel_size=5, strides=2),

    # '''TODO: define convolutional layers with 48 5x5 filters and 2x2 stride'''
    # # [your Conv layer here]
    Conv2D(filters=48, kernel_size=5, strides=2),

    # '''TODO: define two convolutional layers with 64 3x3 filters and 2x2 stride'''
    # # [your Conv layers here]
    Conv2D(filters=64, kernel_size=3, strides=2),

    Flatten(),
    
    # Fully connected layer and output
    Dense(units=128, activation='relu'),

    # '''TODO: define the output dimension of the last Dense layer. 
    # Pay attention to the space the agent needs to act in'''
    # # [TODO: your Dense layer here]
    Dense(units=n_actions)
  
  ])
  return model

pong_model = create_pong_model()

# %% [markdown]
# Since we've already defined the action function, `choose_action(model, observation)`, we don't need to define it again. Instead, we'll be able to reuse it later on by passing in our new model we've just created, `pong_model`. This is awesome because our action function provides a modular and generalizable method for all sorts of RL agents!

# %% [markdown]
# ## 3.8 Pong-specific functions
#
# In Part 1 (Cartpole), we implemented some key functions and classes to build and train our RL agent -- `choose_action(model, observation)` and the `Memory` class, for example. However, in getting ready to apply these to a new game like Pong, we might need to make some slight modifications.
#
# Namely, we need to think about what happens when a game ends. In Pong, we know a game has ended if the reward is +1 (we won!) or -1 (we lost unfortunately). Otherwise, we expect the reward at a timestep to be zero -- the players (or agents) are just playing eachother. So, after a game ends, we will need to reset the reward to zero when a game ends. This will result in a modified reward function.

# %%
### Pong reward function ###

# Compute normalized, discounted rewards for Pong (i.e., return)
# Arguments:
#   rewards: reward at timesteps in episode
#   gamma: discounting factor. Note increase to 0.99 -- rate of depreciation will be slower.
# Returns:
#   normalized discounted reward
def discount_rewards(rewards, gamma=0.99): 
  discounted_rewards = np.zeros_like(rewards)
  R = 0
  for t in reversed(range(0, len(rewards))):
      # NEW: Reset the sum if the reward is not 0 (the game has ended!)
      if rewards[t] != 0:
        R = 0
      # update the total discounted reward as before
      R = R * gamma + rewards[t]
      discounted_rewards[t] = R
      
  return normalize(discounted_rewards)

# %% [markdown]
# Additionally, we have to consider the nature of the observations in the Pong environment, and how they will be fed into our network. Our observations in this case are images. Before we input an image into our network, we'll do a bit of pre-processing to crop and scale, clean up the background colors to a single color, and set the important game elements to a single color. Let's use this function to visualize what a single observation might look like before and after pre-processing.

# %%
observation = env.reset()
for i in range(30):
  action = np.random.choice(n_actions)
  observation, _,_,_ = env.step(action)
observation_pp = mdl.lab3.preprocess_pong(observation)

f = plt.figure(figsize=(10,3))
ax = f.add_subplot(121)
ax2 = f.add_subplot(122)
ax.imshow(observation); ax.grid(False);
ax2.imshow(np.squeeze(observation_pp)); ax2.grid(False); plt.title('Preprocessed Observation');

# %% [markdown]
# Let's also consider the fact that, unlike CartPole, the Pong environment has an additional element of uncertainty -- regardless of what action the agent takes, we don't know how the opponent will play. That is, the environment is changing over time, based on *both* the actions we take and the actions of the opponent, which result in motion of the ball and motion of the paddles.
#
# Therefore, to capture the dynamics, we also consider how the environment changes by looking at the difference between a previous observation (image frame) and the current observation (image frame). We've implemented a helper function, `pong_change`, that pre-processes two frames, calculates the change between the two, and then re-normalizes the values. Let's inspect this to visualize how the environment can change:

# %%
next_observation, _,_,_ = env.step(np.random.choice(n_actions))
diff = mdl.lab3.pong_change(observation, next_observation)

f, ax = plt.subplots(1, 3, figsize=(15,15))
for a in ax:
  a.grid(False)
  a.axis("off")
ax[0].imshow(observation); ax[0].set_title('Previous Frame');
ax[1].imshow(next_observation); ax[1].set_title('Current Frame');
ax[2].imshow(np.squeeze(diff)); ax[2].set_title('Difference (Model Input)');

# %% [markdown]
# What do you notice? How and why might these pre-processing changes be important for training our RL algorithm? How and why might consideration of the difference between frames be important for training and performance?

# %% [markdown]
# ### Rollout function
#
# We're now set up to define our key action algorithm for the game of Pong, which will ultimately be used to train our Pong agent. This function can be thought of as a "rollout", where the agent will 1) make an observation of the environment, 2) select an action based on its state in the environment, 3) execute a policy based on that action, resulting in some reward and a change to the environment, and 4) finally add memory of that action-reward to its `Memory` buffer. We will define this algorithm in the `collect_rollout` function below, and use it soon within a training block.
#
# Earlier you visually inspected the raw environment frames, the pre-processed frames, and the difference between previous and current frames. As you may have gathered, in a dynamic game like Pong, it can actually be helpful to consider the difference between two consecutive observations. This gives us information about the movement between frames -- how the game is changing. We will do this using the `pong_change` function we explored above (which also pre-processes frames for us).
#
# We will use differences between frames as the input on which actions will be selected. These observation changes will be forward propagated through our Pong agent, the CNN network model, which will then predict the next action to take based on this observation. The raw reward will be computed. The observation, action, and reward will be recorded into memory. This will loop until a particular game ends -- the rollout is completed.
#
# For now, we will define `collect_rollout` such that a batch of observations (i.e., from a batch of agent-environment worlds) can be processed serially (i.e., one at a time, in sequence). We will later utilize a parallelized version of this function that will parallelize batch processing to help speed up training! Let's get to it.

# %%
### Rollout function ###

# Key steps for agent's operation in the environment, until completion of a rollout.
# An observation is drawn; the agent (controlled by model) selects an action;
#   the agent executes that action in the environment and collects rewards;
#   information is added to memory.
# This is repeated until the completion of the rollout -- the Pong game ends.
# Processes multiple batches serially.
#
# Arguments:
#   batch_size: number of batches, to be processed serially
#   env: environment
#   model: Pong agent model
#   choose_action: choose_action function
# Returns:
#   memories: array of Memory buffers, of length batch_size, corresponding to the
#     episode executions from the rollout
def collect_rollout(batch_size, env, model, choose_action):

  # Holder array for the Memory buffers
  memories = []

  # Process batches serially by iterating through them
  for b in range(batch_size):

    # Instantiate Memory buffer, restart the environment
    memory = Memory()
    next_observation = env.reset()
    previous_frame = next_observation
    done = False # tracks whether the episode (game) is done or not

    while not done:

      current_frame = next_observation

      # '''TODO: determine the observation change.
      # Hint: this is the difference between the past two frames'''
      frame_diff = mdl.lab3.pong_change(previous_frame, current_frame) # TODO

      # '''TODO: choose an action for the pong model, using the frame difference, and evaluate'''
      action = choose_action(model, frame_diff) # TODO

      # Take the chosen action
      next_observation, reward, done, info = env.step(action)

      # '''TODO: save the observed frame difference, the action that was taken, and the resulting reward!'''
      memory.add_to_memory(frame_diff, action, reward)
          
      previous_frame = current_frame
    
    # Add the memory from this batch to the array of all Memory buffers
    memories.append(memory)
  
  return memories

# %% [markdown]
# To get a sense of what is encapsulated by `collect_rollout`, we will instantiate an *untrained* Pong model, run a single rollout using this model, save the memory, and play back the observations the model sees. Note that these will be frame *differences*.

# %%
### Rollout with untrained Pong model ###

# Model
test_model = create_pong_model()

# Rollout with single batch
single_batch_size = 1
memories = collect_rollout(single_batch_size, env, test_model, choose_action)
rollout_video = mdl.lab3.save_video_of_memory(memories[0], "Pong-Random-Agent.mp4")

# Play back video of memories
mdl.lab3.play_video(rollout_video)
# Out:
#         <video controls >
#             <source src="data:video/mp4;base64,..." type="video/mp4" />
#         </video>

# %% [markdown]
# ## 3.9 Training Pong
#
# We're now all set up to start training our RL algorithm and agent for the game of Pong! We've already defined the following:
#
# 1. Loss function, `compute_loss`, and backpropagation step, `train_step`. Our loss function employs policy gradient learning. `train_step` executes a single forward pass and backpropagation gradient update.
# 2. RL agent algorithm: `collect_rollout`. Serially processes batches of episodes, executing actions in the environment, collecting rewards, and saving these to `Memory`.
#
# We will use these functions to train the Pong agent.
#
# In the training block, episodes will be executed by agents in the environment via the RL algorithm defined in the `collect_rollout` function. Since RL agents start off with literally zero knowledge of their environment, it can often take a long time to train them and achieve stable behavior. To alleviate this, we have implemented a parallelized version of the RL algorithm, `parallelized_collect_rollout`, which you can use to accelerate training across multiple parallel batches.
#
# For training, information in the `Memory` buffer from all these batches will be aggregated (after all episodes, i.e., games, end). Discounted rewards will be computed, and this information will be used to execute a training step. Memory will be cleared, and we will do it all over again!
#
# Let's run the code block to train our Pong agent. Note that, even with parallelization, completing training and getting stable behavior will take quite a bit of time (estimated at least a couple of hours). We will again visualize the evolution of the total reward as a function of training to get a sense of how the agent is learning.

# %%
### Hyperparameters and setup for training ###
# Rerun this cell if you want to re-initialize the training process
#   (i.e., create new model, reset loss, etc)

# Hyperparameters
learning_rate = 1e-3
MAX_ITERS = 1000 # increase the maximum to train longer
batch_size = 5 # number of batches to run

# Model, optimizer
pong_model = create_pong_model()
optimizer = tf.keras.optimizers.Adam(learning_rate)
iteration = 0 # counter for training steps

# Plotting
smoothed_reward = mdl.util.LossHistory(smoothing_factor=0.9)
smoothed_reward.append(0) # start the reward at zero for baseline comparison
plotter = mdl.util.PeriodicPlotter(sec=15, xlabel='Iterations', ylabel='Win Percentage (%)')

# Batches and environment
# To parallelize batches, we need to make multiple copies of the environment.
envs = [create_pong_env() for _ in range(batch_size)] # For parallelization

# %%
### Training Pong ###
# You can run this cell and stop it anytime in the middle of training to save 
#   a progress video (see next codeblock). To continue training, simply run this 
#   cell again, your model will pick up right where it left off. To reset training,
#   you need to run the cell above. 

games_to_win_episode = 21 # this is set by OpenAI gym and cannot be changed.

# Main training loop
while iteration < MAX_ITERS:

  plotter.plot(smoothed_reward.get())

  tic = time.time()
  # RL agent algorithm. By default, uses serial batch processing.
  # memories = collect_rollout(batch_size, env, pong_model, choose_action)

  # Parallelized version. Uncomment line below (and comment out line above) to parallelize
  memories = mdl.lab3.parallelized_collect_rollout(batch_size, envs, pong_model, choose_action)
  print(time.time()-tic)

  # Aggregate memories from multiple batches
  batch_memory = aggregate_memories(memories)

  # Track performance based on win percentage (calculated from rewards)
  total_wins = sum(np.array(batch_memory.rewards) == 1)
  total_games = sum(np.abs(np.array(batch_memory.rewards)))
  win_rate = total_wins / total_games
  smoothed_reward.append(100 * win_rate)
  
  # Training!
  train_step(
      pong_model,
      optimizer,
      observations = np.stack(batch_memory.observations, 0),
      actions = np.array(batch_memory.actions),
      discounted_rewards = discount_rewards(batch_memory.rewards)
  )

  # Save a video of progress -- this can be played back later
  if iteration % 100 == 0:
    mdl.lab3.save_video_of_model(pong_model, "Pong-v0", 
                                                suffix="_"+str(iteration))
    
  iteration += 1 # Mark next episode

# %% [markdown]
# Finally we can put our trained agent to the test! It will play in a newly instantiated Pong environment against the "computer", a base AI system for Pong. Your agent plays as the green paddle. Let's watch the match instant replay!

# %%
latest_pong = mdl.lab3.save_video_of_model(
    pong_model, "Pong-v0", suffix="_latest")
mdl.lab3.play_video(latest_pong, width=400)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2d016dea2b81> in <module>()
# ----> 1 latest_pong = mdl.lab3.save_video_of_model(
#       2     pong_model, "Pong-v0", suffix="_latest")
#       3 mdl.lab3.play_video(latest_pong, width=400)
#
# NameError: name 'mdl' is not defined

# %% [markdown]
# ## 3.10 Conclusion and submission information
#
# That's it! Congratulations on training two RL agents and putting them to the test! We encourage you to consider the following:
#
# *   How does the agent perform?
# *   Could you train it for shorter amounts of time  and still perform well?
# * What are some limitations of the current representation i.e., difference of current and previous frames? How is this reflected in the agent's behavior? What could be done to generate an improved representation?
# * How does the complexity of Pong relative to CartPole alter the rate at which the agent learns and its performance?
# * What are some things you could change about the agent or the learning process to potentially improve performance?
#
# Try to optimize your **Pong** model and algorithm to achieve improved performance.  **MIT students and affiliates will be eligible for prizes during the IAP offering.** To enter the competition, MIT students and affiliates should upload the following to the course Canvas:
#
# * Jupyter notebook with the code you used to generate your results, **with the Pong training executed**;
# * saved video of your Pong agent competing;
# * a description and/or diagram of the architecture, settings, and hyperparameters you used to generate your result -- if there are any additional or interesting modifications you made to the template code, please include these in your description;
# * discussion of why these modifications helped improve performance.
#
# Good luck!
